# %% [markdown]
# # 2. Run Nucleus Segmentation Model

# %% [markdown]
# gg-napari-env

# %%
from napari_czifile2 import napari_get_reader
from cellpose import models, core
from cellpose.io import logger_setup
import torch 
import numpy as np
import numpy as np
import os 
from plotting import * 
import warnings
warnings.filterwarnings("ignore")
use_GPU = core.use_gpu()
torch.cuda.empty_cache()
print('>>> GPU activated? %d'%use_GPU)
logger_setup()
# Out:
# Initializing plotting package
# >>> GPU activated? 1
# 2025-05-24 11:14:28,751 [INFO] WRITING LOG OUTPUT TO /home/tracking/.cellpose/run.log
# 2025-05-24 11:14:28,752 [INFO]
# cellpose version: 	3.1.0
# platform:       	linux
# python version: 	3.12.8
# torch version:  	2.5.1+cu124
# (<Logger cellpose.io (INFO)>, PosixPath('/home/tracking/.cellpose/run.log'))

# %%
raw_data_dirs = os.listdir('../../../RNA-FISH-raw-data/')
raw_data_dirs
# Out:
# ['20250508 P14 T 9E89-b1-546 9E99-B2-647 DAPI',
#  '20250325 6 9e198-b3-488 9e197-b1-546 9e196-b2-647 dapi',
#  '20250307 B1 P14 U34-B3-546 Chymotrypsin-B2-647 DAPI',
#  '20250328 1 P14 T79-intergenic-b2-647 T79-exonic-b1-546 DAPI',
#  '20250328 5 P14 LOC603-b3-488 9E108-b1-546 9E116-b2-647 DAPI',
#  '20250325 5 p14 g1-b1-546 lnc7-b2-647 dapi',
#  '20250508 P14 T 9E99-b2-594 LOC105286072-B5-647 DAPI',
#  '20250307 C2 stacks',
#  '20250324 A1 stacks',
#  '20250328 2 P14 R2-b3-488 Q1-b1-546 Lnc6-b2-647 DAPI',
#  '20250523 C P14 T U54-647 Lnc4-546 DAPI',
#  '20250523 A P14 T 9E213-546 9E214-488 Intergenic-647 DAPI',
#  '20250325 4 p14 u34-b3-488 lnc4-b1-546 u21-b5-647 dapi',
#  '20250328 3 P14 Lnc3-b3-488 L16-b2-594 Lnc2-b5-647 DAPI',
#  '20250324 A2 stacks',
#  '20250306 C1 stacks',
#  '20250328 4 P14 9E129-b3-488 LOC104-b1-546 9E116-b2-647 dapi',
#  '20250523 B P14 T 9E88-546 Lnc-647 DAPI']

# %%
input = '20250523 C'
input = [d for d in raw_data_dirs if input in d][0]
print(f'Using {input} as input directory')
input_dir = f'../../../RNA-FISH-raw-data/{input}/'
assert os.path.exists(input_dir), 'Input directory does not exist'
czi_files = [f for f in os.listdir(input_dir) if f.endswith('.czi')]
print(f"Found {len(czi_files)} czi files in {input_dir}")
print(czi_files)
# Out:
# Using 20250523 C P14 T U54-647 Lnc4-546 DAPI as input directory
# Found 4 czi files in ../../../RNA-FISH-raw-data/20250523 C P14 T U54-647 Lnc4-546 DAPI/
# ['20250523 C sample 4 stack.czi', '20250523 C sample 2 stack.czi', '20250523 C sample 3 stack.czi', '20250523 C sample 1 stack.czi']

# %%
# Load trained model 
model_path = '../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs'
model = models.CellposeModel(gpu=True, pretrained_model=model_path)
# Out:
# 2025-05-24 11:14:45,715 [INFO] ** TORCH CUDA version installed and working. **
# 2025-05-24 11:14:45,715 [INFO] >>>> using GPU (CUDA)
# 2025-05-24 11:14:45,759 [INFO] >>>> loading model ../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs
# 2025-05-24 11:14:46,075 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-05-24 11:14:46,077 [INFO] >>>> model diam_labels =  29.437 (mean diameter of training ROIs)

# %%
results_dir = f'../results/{input}'
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
for f in czi_files[:]:
    print(f"Processing {f}")
    file_path = os.path.join(input_dir, f)
    reader = napari_get_reader(file_path)
    if reader is not None:
        layer_data = reader(file_path)
        image_data, metadata, layer_type = layer_data[0]
        # Remove singleton dimension 
        image_data = np.squeeze(image_data)  
        print("Metadata:", metadata)
        print("Image shape:", image_data.shape)  
        print(f"Number of NaN pixels: {np.sum(np.isnan(image_data))}")

        pixel_x = metadata['scale'][2]
        print(f"Pixel size: {pixel_x} um")

        xy_resolution = image_data.shape[-1] 
        print(f"XY resolution: {xy_resolution} pixels")

        nucleus_diameter = 3 / pixel_x
        print(f"Nucleus diameter: {nucleus_diameter} pixels") 
        
        z_slices = image_data.shape[0]
        print(f"Z slices: {z_slices}")

        z_um = metadata['scale'][1]
        print(f"Z resolution: {z_um} um")

        dapi_index = metadata['name'].index([name for name in metadata['name'] if 'DAPI' in name][0])
        print(f"DAPI channel index: {dapi_index}")

        non_dapi_channels = [(i, metadata['name'][i]) for i in range(len(metadata['name'])) if i != dapi_index]
        print(f"Non-DAPI channels: {non_dapi_channels}")

        all_rois = np.zeros_like(image_data[:, dapi_index, :, :], dtype=np.uint16)
        for z in range(z_slices):
            image_data_z = image_data[z, dapi_index, :, :]
            print(f"Z={z} | shape={image_data_z.shape} | dtype={image_data_z.dtype} | min={image_data_z.min()} | max={image_data_z.max()}")
            try:
                rois, flows, styles = model.eval(image_data_z, diameter=nucleus_diameter)
                print(f"Identified {rois.max()} nuclei at z={z}")
            except Exception as e:
                print(f"Error at z={z}: {e}")
                continue
            print(f"Identified {rois.max()} nuclei")
            all_rois[z, :, :] = rois

        # Save the masks to a file 
        all_rois_path = os.path.join(results_dir, f.replace('.czi', f'_rois.npy'))
        np.save(all_rois_path, all_rois)
        print(f"ROIs saved to {all_rois_path}")
# Out:
# Processing 20250523 C sample 4 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (94, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 94
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=0
# Identified 6 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 28 nuclei at z=1
# Identified 28 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 55 nuclei at z=2
# Identified 55 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 92 nuclei at z=3
# Identified 92 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 130 nuclei at z=4
# Identified 130 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 158 nuclei at z=5
# Identified 158 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 204 nuclei at z=6
# Identified 204 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 240 nuclei at z=7
# Identified 240 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 258 nuclei at z=8
# Identified 258 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 295 nuclei at z=9
# Identified 295 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 310 nuclei at z=10
# Identified 310 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 352 nuclei at z=11
# Identified 352 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 352 nuclei at z=12
# Identified 352 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 367 nuclei at z=13
# Identified 367 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 382 nuclei at z=14
# Identified 382 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 361 nuclei at z=15
# Identified 361 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 372 nuclei at z=16
# Identified 372 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 410 nuclei at z=17
# Identified 410 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=18
# Identified 415 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 408 nuclei at z=19
# Identified 408 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 409 nuclei at z=20
# Identified 409 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 418 nuclei at z=21
# Identified 418 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 456 nuclei at z=22
# Identified 456 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 473 nuclei at z=23
# Identified 473 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 459 nuclei at z=24
# Identified 459 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 447 nuclei at z=25
# Identified 447 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 470 nuclei at z=26
# Identified 470 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 490 nuclei at z=27
# Identified 490 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 517 nuclei at z=28
# Identified 517 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 531 nuclei at z=29
# Identified 531 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=30
# Identified 536 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 538 nuclei at z=31
# Identified 538 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 540 nuclei at z=32
# Identified 540 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 519 nuclei at z=33
# Identified 519 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 474 nuclei at z=34
# Identified 474 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 497 nuclei at z=35
# Identified 497 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 487 nuclei at z=36
# Identified 487 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=37
# Identified 504 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 496 nuclei at z=38
# Identified 496 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 531 nuclei at z=39
# Identified 531 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 553 nuclei at z=40
# Identified 553 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 559 nuclei at z=41
# Identified 559 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 577 nuclei at z=42
# Identified 577 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 636 nuclei at z=43
# Identified 636 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 623 nuclei at z=44
# Identified 623 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 628 nuclei at z=45
# Identified 628 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 645 nuclei at z=46
# Identified 645 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 572 nuclei at z=47
# Identified 572 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 585 nuclei at z=48
# Identified 585 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 554 nuclei at z=49
# Identified 554 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 563 nuclei at z=50
# Identified 563 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 546 nuclei at z=51
# Identified 546 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=52
# Identified 535 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=53
# Identified 536 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=54
# Identified 518 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 505 nuclei at z=55
# Identified 505 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=56
# Identified 439 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 437 nuclei at z=57
# Identified 437 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 390 nuclei at z=58
# Identified 390 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 352 nuclei at z=59
# Identified 352 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 323 nuclei at z=60
# Identified 323 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 321 nuclei at z=61
# Identified 321 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 292 nuclei at z=62
# Identified 292 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 236 nuclei at z=63
# Identified 236 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=248
# Identified 211 nuclei at z=64
# Identified 211 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 174 nuclei at z=65
# Identified 174 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 115 nuclei at z=66
# Identified 115 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=228
# Identified 107 nuclei at z=67
# Identified 107 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 76 nuclei at z=68
# Identified 76 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 38 nuclei at z=69
# Identified 38 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 28 nuclei at z=70
# Identified 28 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 12 nuclei at z=71
# Identified 12 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 2 nuclei at z=72
# Identified 2 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=73
# Identified 0 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=74
# Identified 0 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:15:59,941 [INFO] No cell pixels found.
# Identified 0 nuclei at z=75
# Identified 0 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:00,516 [INFO] No cell pixels found.
# Identified 0 nuclei at z=76
# Identified 0 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:01,097 [INFO] No cell pixels found.
# Identified 0 nuclei at z=77
# Identified 0 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:01,704 [INFO] No cell pixels found.
# Identified 0 nuclei at z=78
# Identified 0 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:02,310 [INFO] No cell pixels found.
# Identified 0 nuclei at z=79
# Identified 0 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:02,912 [INFO] No cell pixels found.
# Identified 0 nuclei at z=80
# Identified 0 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=81
# Identified 0 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:04,244 [INFO] No cell pixels found.
# Identified 0 nuclei at z=82
# Identified 0 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:04,878 [INFO] No cell pixels found.
# Identified 0 nuclei at z=83
# Identified 0 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:05,492 [INFO] No cell pixels found.
# Identified 0 nuclei at z=84
# Identified 0 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:06,108 [INFO] No cell pixels found.
# Identified 0 nuclei at z=85
# Identified 0 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=86
# Identified 0 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=87
# Identified 0 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=88
# Identified 0 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 0 nuclei at z=89
# Identified 0 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=171
# Identified 0 nuclei at z=90
# Identified 0 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=139
# Identified 4 nuclei at z=91
# Identified 4 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=163
# Identified 1 nuclei at z=92
# Identified 1 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=209
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# ROIs saved to ../results/20250523 C P14 T U54-647 Lnc4-546 DAPI/20250523 C sample 4 stack_rois.npy
# Processing 20250523 C sample 2 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (94, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 94
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=0
# Identified 1 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:34,985 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 2 nuclei at z=2
# Identified 2 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:36,531 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:37,142 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:37,787 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:38,401 [INFO] No cell pixels found.
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:39,017 [INFO] No cell pixels found.
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:39,645 [INFO] No cell pixels found.
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:16:40,272 [INFO] No cell pixels found.
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=10
# Identified 1 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=11
# Identified 1 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=12
# Identified 3 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 7 nuclei at z=13
# Identified 7 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 19 nuclei at z=14
# Identified 19 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 36 nuclei at z=15
# Identified 36 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 53 nuclei at z=16
# Identified 53 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 83 nuclei at z=17
# Identified 83 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 119 nuclei at z=18
# Identified 119 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 152 nuclei at z=19
# Identified 152 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 191 nuclei at z=20
# Identified 191 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 243 nuclei at z=21
# Identified 243 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 281 nuclei at z=22
# Identified 281 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 329 nuclei at z=23
# Identified 329 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=24
# Identified 355 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=25
# Identified 359 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 392 nuclei at z=26
# Identified 392 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 414 nuclei at z=27
# Identified 414 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 412 nuclei at z=28
# Identified 412 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 394 nuclei at z=29
# Identified 394 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 411 nuclei at z=30
# Identified 411 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 390 nuclei at z=31
# Identified 390 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=32
# Identified 425 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 413 nuclei at z=33
# Identified 413 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 412 nuclei at z=34
# Identified 412 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 412 nuclei at z=35
# Identified 412 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 441 nuclei at z=36
# Identified 441 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 440 nuclei at z=37
# Identified 440 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 434 nuclei at z=38
# Identified 434 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 434 nuclei at z=39
# Identified 434 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 445 nuclei at z=40
# Identified 445 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=41
# Identified 384 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 367 nuclei at z=42
# Identified 367 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 419 nuclei at z=43
# Identified 419 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 380 nuclei at z=44
# Identified 380 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 369 nuclei at z=45
# Identified 369 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 339 nuclei at z=46
# Identified 339 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 367 nuclei at z=47
# Identified 367 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 306 nuclei at z=48
# Identified 306 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 306 nuclei at z=49
# Identified 306 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 288 nuclei at z=50
# Identified 288 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 314 nuclei at z=51
# Identified 314 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 318 nuclei at z=52
# Identified 318 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 316 nuclei at z=53
# Identified 316 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 328 nuclei at z=54
# Identified 328 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 340 nuclei at z=55
# Identified 340 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 320 nuclei at z=56
# Identified 320 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 353 nuclei at z=57
# Identified 353 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 362 nuclei at z=58
# Identified 362 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 353 nuclei at z=59
# Identified 353 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=60
# Identified 359 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 369 nuclei at z=61
# Identified 369 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 371 nuclei at z=62
# Identified 371 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 388 nuclei at z=63
# Identified 388 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=64
# Identified 359 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 336 nuclei at z=65
# Identified 336 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 310 nuclei at z=66
# Identified 310 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 318 nuclei at z=67
# Identified 318 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 333 nuclei at z=68
# Identified 333 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 353 nuclei at z=69
# Identified 353 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 344 nuclei at z=70
# Identified 344 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 291 nuclei at z=71
# Identified 291 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 289 nuclei at z=72
# Identified 289 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 252 nuclei at z=73
# Identified 252 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 250 nuclei at z=74
# Identified 250 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 251 nuclei at z=75
# Identified 251 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 269 nuclei at z=76
# Identified 269 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 231 nuclei at z=77
# Identified 231 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 221 nuclei at z=78
# Identified 221 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 211 nuclei at z=79
# Identified 211 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 191 nuclei at z=80
# Identified 191 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 178 nuclei at z=81
# Identified 178 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=249
# Identified 182 nuclei at z=82
# Identified 182 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 161 nuclei at z=83
# Identified 161 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 128 nuclei at z=84
# Identified 128 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 110 nuclei at z=85
# Identified 110 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 113 nuclei at z=86
# Identified 113 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 85 nuclei at z=87
# Identified 85 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 57 nuclei at z=88
# Identified 57 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 47 nuclei at z=89
# Identified 47 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=90
# Identified 33 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 14 nuclei at z=91
# Identified 14 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 3 nuclei at z=92
# Identified 3 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:17:51,068 [INFO] No cell pixels found.
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# ROIs saved to ../results/20250523 C P14 T U54-647 Lnc4-546 DAPI/20250523 C sample 2 stack_rois.npy
# Processing 20250523 C sample 3 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (94, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 94
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=1
# Identified 6 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 2 nuclei at z=3
# Identified 2 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=4
# Identified 1 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:18:15,772 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 4 nuclei at z=6
# Identified 4 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=7
# Identified 1 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=8
# Identified 1 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=9
# Identified 1 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=11
# Identified 0 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=12
# Identified 1 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=13
# Identified 0 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:18:23,378 [INFO] No cell pixels found.
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 9 nuclei at z=15
# Identified 9 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 16 nuclei at z=16
# Identified 16 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 50 nuclei at z=17
# Identified 50 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 70 nuclei at z=18
# Identified 70 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 94 nuclei at z=19
# Identified 94 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 113 nuclei at z=20
# Identified 113 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 142 nuclei at z=21
# Identified 142 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 154 nuclei at z=22
# Identified 154 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 193 nuclei at z=23
# Identified 193 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 246 nuclei at z=24
# Identified 246 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 290 nuclei at z=25
# Identified 290 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 288 nuclei at z=26
# Identified 288 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 330 nuclei at z=27
# Identified 330 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 357 nuclei at z=28
# Identified 357 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 383 nuclei at z=29
# Identified 383 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=30
# Identified 415 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 437 nuclei at z=31
# Identified 437 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 482 nuclei at z=32
# Identified 482 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 489 nuclei at z=33
# Identified 489 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 529 nuclei at z=34
# Identified 529 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 561 nuclei at z=35
# Identified 561 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=36
# Identified 578 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 587 nuclei at z=37
# Identified 587 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 598 nuclei at z=38
# Identified 598 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 579 nuclei at z=39
# Identified 579 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 577 nuclei at z=40
# Identified 577 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 616 nuclei at z=41
# Identified 616 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 608 nuclei at z=42
# Identified 608 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 604 nuclei at z=43
# Identified 604 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 585 nuclei at z=44
# Identified 585 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 559 nuclei at z=45
# Identified 559 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 548 nuclei at z=46
# Identified 548 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 497 nuclei at z=47
# Identified 497 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 485 nuclei at z=48
# Identified 485 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 459 nuclei at z=49
# Identified 459 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=50
# Identified 439 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 452 nuclei at z=51
# Identified 452 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 442 nuclei at z=52
# Identified 442 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 414 nuclei at z=53
# Identified 414 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 409 nuclei at z=54
# Identified 409 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 419 nuclei at z=55
# Identified 419 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=56
# Identified 417 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 399 nuclei at z=57
# Identified 399 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 422 nuclei at z=58
# Identified 422 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=252
# Identified 426 nuclei at z=59
# Identified 426 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 433 nuclei at z=60
# Identified 433 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 419 nuclei at z=61
# Identified 419 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 399 nuclei at z=62
# Identified 399 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 392 nuclei at z=63
# Identified 392 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=64
# Identified 384 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 367 nuclei at z=65
# Identified 367 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 353 nuclei at z=66
# Identified 353 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 343 nuclei at z=67
# Identified 343 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 340 nuclei at z=68
# Identified 340 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 347 nuclei at z=69
# Identified 347 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 309 nuclei at z=70
# Identified 309 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 308 nuclei at z=71
# Identified 308 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 301 nuclei at z=72
# Identified 301 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=236
# Identified 273 nuclei at z=73
# Identified 273 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 252 nuclei at z=74
# Identified 252 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 263 nuclei at z=75
# Identified 263 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 258 nuclei at z=76
# Identified 258 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 232 nuclei at z=77
# Identified 232 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 242 nuclei at z=78
# Identified 242 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=227
# Identified 219 nuclei at z=79
# Identified 219 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# Identified 191 nuclei at z=80
# Identified 191 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 181 nuclei at z=81
# Identified 181 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 148 nuclei at z=82
# Identified 148 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 127 nuclei at z=83
# Identified 127 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 94 nuclei at z=84
# Identified 94 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 93 nuclei at z=85
# Identified 93 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=228
# Identified 76 nuclei at z=86
# Identified 76 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 38 nuclei at z=87
# Identified 38 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 13 nuclei at z=88
# Identified 13 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 1 nuclei at z=89
# Identified 1 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=90
# Identified 1 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=92
# Identified 0 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# ROIs saved to ../results/20250523 C P14 T U54-647 Lnc4-546 DAPI/20250523 C sample 3 stack_rois.npy
# Processing 20250523 C sample 1 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (94, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 94
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:01,914 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:02,398 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:02,854 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:03,338 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:03,826 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:20:04,311 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=7
# Identified 3 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=8
# Identified 1 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=9
# Identified 3 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 22 nuclei at z=10
# Identified 22 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 46 nuclei at z=11
# Identified 46 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 69 nuclei at z=12
# Identified 69 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 96 nuclei at z=13
# Identified 96 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 130 nuclei at z=14
# Identified 130 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 143 nuclei at z=15
# Identified 143 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 167 nuclei at z=16
# Identified 167 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 207 nuclei at z=17
# Identified 207 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 232 nuclei at z=18
# Identified 232 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 241 nuclei at z=19
# Identified 241 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 266 nuclei at z=20
# Identified 266 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 284 nuclei at z=21
# Identified 284 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 323 nuclei at z=22
# Identified 323 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 332 nuclei at z=23
# Identified 332 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 342 nuclei at z=24
# Identified 342 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=25
# Identified 355 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 380 nuclei at z=26
# Identified 380 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 345 nuclei at z=27
# Identified 345 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 364 nuclei at z=28
# Identified 364 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 377 nuclei at z=29
# Identified 377 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 351 nuclei at z=30
# Identified 351 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 329 nuclei at z=31
# Identified 329 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 369 nuclei at z=32
# Identified 369 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=33
# Identified 384 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 400 nuclei at z=34
# Identified 400 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=35
# Identified 417 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=36
# Identified 417 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 422 nuclei at z=37
# Identified 422 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 410 nuclei at z=38
# Identified 410 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 412 nuclei at z=39
# Identified 412 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 424 nuclei at z=40
# Identified 424 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 400 nuclei at z=41
# Identified 400 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 430 nuclei at z=42
# Identified 430 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 414 nuclei at z=43
# Identified 414 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=44
# Identified 417 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=45
# Identified 425 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 416 nuclei at z=46
# Identified 416 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 423 nuclei at z=47
# Identified 423 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 428 nuclei at z=48
# Identified 428 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 444 nuclei at z=49
# Identified 444 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 476 nuclei at z=50
# Identified 476 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 495 nuclei at z=51
# Identified 495 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=52
# Identified 504 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 483 nuclei at z=53
# Identified 483 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 449 nuclei at z=54
# Identified 449 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 465 nuclei at z=55
# Identified 465 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 464 nuclei at z=56
# Identified 464 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 472 nuclei at z=57
# Identified 472 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 466 nuclei at z=58
# Identified 466 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 469 nuclei at z=59
# Identified 469 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 494 nuclei at z=60
# Identified 494 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 452 nuclei at z=61
# Identified 452 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 451 nuclei at z=62
# Identified 451 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 445 nuclei at z=63
# Identified 445 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 453 nuclei at z=64
# Identified 453 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 426 nuclei at z=65
# Identified 426 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 397 nuclei at z=66
# Identified 397 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=67
# Identified 425 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 385 nuclei at z=68
# Identified 385 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 369 nuclei at z=69
# Identified 369 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 345 nuclei at z=70
# Identified 345 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 328 nuclei at z=71
# Identified 328 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 279 nuclei at z=72
# Identified 279 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 256 nuclei at z=73
# Identified 256 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 235 nuclei at z=74
# Identified 235 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 189 nuclei at z=75
# Identified 189 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 195 nuclei at z=76
# Identified 195 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 175 nuclei at z=77
# Identified 175 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 137 nuclei at z=78
# Identified 137 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 84 nuclei at z=79
# Identified 84 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 47 nuclei at z=80
# Identified 47 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 38 nuclei at z=81
# Identified 38 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 26 nuclei at z=82
# Identified 26 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 12 nuclei at z=83
# Identified 12 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=84
# Identified 1 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:18,208 [INFO] No cell pixels found.
# Identified 0 nuclei at z=85
# Identified 0 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:18,865 [INFO] No cell pixels found.
# Identified 0 nuclei at z=86
# Identified 0 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:19,510 [INFO] No cell pixels found.
# Identified 0 nuclei at z=87
# Identified 0 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:20,115 [INFO] No cell pixels found.
# Identified 0 nuclei at z=88
# Identified 0 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:20,748 [INFO] No cell pixels found.
# Identified 0 nuclei at z=89
# Identified 0 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:21,347 [INFO] No cell pixels found.
# Identified 0 nuclei at z=90
# Identified 0 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:21,958 [INFO] No cell pixels found.
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:22,570 [INFO] No cell pixels found.
# Identified 0 nuclei at z=92
# Identified 0 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-05-24 11:21:23,205 [INFO] No cell pixels found.
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# ROIs saved to ../results/20250523 C P14 T U54-647 Lnc4-546 DAPI/20250523 C sample 1 stack_rois.npy

# %% [markdown]
# ## Run on all files

# %%
raw_data_dirs = os.listdir('../../../RNA-FISH-raw-data/')
raw_data_p14 = [d for d in raw_data_dirs if '14' in d]
raw_data_p14
# Out:
# ['20250307 B1 P14 U34-B3-546 Chymotrypsin-B2-647 DAPI',
#  '20250328 1 P14 T79-intergenic-b2-647 T79-exonic-b1-546 DAPI',
#  '20250328 5 P14 LOC603-b3-488 9E108-b1-546 9E116-b2-647 DAPI',
#  '20250325 5 p14 g1-b1-546 lnc7-b2-647 dapi',
#  '20250328 2 P14 R2-b3-488 Q1-b1-546 Lnc6-b2-647 DAPI',
#  '20250328 4 P14 9E129-b3-488 LOC104-b1-546 9E116-b2-647 dapi',
#  '20250325 4 p14 u34-b3-488 lnc4-b1-546 u21-b5-647 dapi',
#  '20250328 3 P14 Lnc3-b3-488 L16-b2-594 Lnc2-b5-647 DAPI']

# %%
for input in raw_data_p14: 

    input_dir = f'../raw-data/{input}/'
    assert os.path.exists(input_dir), 'Input directory does not exist'
    czi_files = [f for f in os.listdir(input_dir) if f.endswith('.czi')]
    print(f"Found {len(czi_files)} czi files in {input_dir}")
    print(czi_files)

    results_dir = f'../results/{input}'
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
        
    for f in czi_files[:]:
        print(f"Processing {f}")
        file_path = os.path.join(input_dir, f)
        reader = napari_get_reader(file_path)
        if reader is not None:
            layer_data = reader(file_path)
            image_data, metadata, layer_type = layer_data[0]
            # Remove singleton dimension 
            image_data = np.squeeze(image_data)  
            print("Metadata:", metadata)
            print("Image shape:", image_data.shape)  
            print(f"Number of NaN pixels: {np.sum(np.isnan(image_data))}")

            pixel_x = metadata['scale'][2]
            print(f"Pixel size: {pixel_x} um")

            xy_resolution = image_data.shape[-1] 
            print(f"XY resolution: {xy_resolution} pixels")

            nucleus_diameter = 3 / pixel_x
            print(f"Nucleus diameter: {nucleus_diameter} pixels") 
            
            z_slices = image_data.shape[0]
            print(f"Z slices: {z_slices}")

            z_um = metadata['scale'][1]
            print(f"Z resolution: {z_um} um")

            dapi_index = metadata['name'].index([name for name in metadata['name'] if 'DAPI' in name][0])
            print(f"DAPI channel index: {dapi_index}")

            non_dapi_channels = [(i, metadata['name'][i]) for i in range(len(metadata['name'])) if i != dapi_index]
            print(f"Non-DAPI channels: {non_dapi_channels}")

            all_rois = np.zeros_like(image_data[:, dapi_index, :, :], dtype=np.uint16)
            for z in range(z_slices):
                image_data_z = image_data[z, dapi_index, :, :]
                print(f"Z={z} | shape={image_data_z.shape} | dtype={image_data_z.dtype} | min={image_data_z.min()} | max={image_data_z.max()}")
                try:
                    rois, flows, styles = model.eval(image_data_z, diameter=nucleus_diameter)
                    print(f"Identified {rois.max()} nuclei at z={z}")
                except Exception as e:
                    print(f"Error at z={z}: {e}")
                    continue
                print(f"Identified {rois.max()} nuclei")
                all_rois[z, :, :] = rois

            # Save the masks to a file 
            all_rois_path = os.path.join(results_dir, f.replace('.czi', f'_rois.npy'))
            np.save(all_rois_path, all_rois)
            print(f"ROIs saved to {all_rois_path}")
# Out:
# Found 5 czi files in ../raw-data/20250307 B1 P14 U34-B3-546 Chymotrypsin-B2-647 DAPI/
# ['20250307 B1 Sample 5 Stack.czi', '20250307 B1 Sample 4 Stack.czi', '20250307 B1 Sample 1 Stack.czi', '20250307 B1 Sample 3 Stack.czi', '20250307 B1 Sample 2 Stack.czi']
# Processing 20250307 B1 Sample 5 Stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 0.5, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (202, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 202
# Z resolution: 0.5 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:42:27,658 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:42:28,158 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=2
# Identified 3 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=3
# Identified 3 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=4
# Identified 5 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 10 nuclei at z=5
# Identified 10 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 12 nuclei at z=6
# Identified 12 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 14 nuclei at z=7
# Identified 14 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 22 nuclei at z=8
# Identified 22 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 31 nuclei at z=9
# Identified 31 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=10
# Identified 33 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 39 nuclei at z=11
# Identified 39 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 46 nuclei at z=12
# Identified 46 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 44 nuclei at z=13
# Identified 44 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 43 nuclei at z=14
# Identified 43 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 44 nuclei at z=15
# Identified 44 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 41 nuclei at z=16
# Identified 41 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 39 nuclei at z=17
# Identified 39 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 36 nuclei at z=18
# Identified 36 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 54 nuclei at z=19
# Identified 54 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 68 nuclei at z=20
# Identified 68 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 79 nuclei at z=21
# Identified 79 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 88 nuclei at z=22
# Identified 88 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 107 nuclei at z=23
# Identified 107 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 129 nuclei at z=24
# Identified 129 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 134 nuclei at z=25
# Identified 134 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 143 nuclei at z=26
# Identified 143 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 164 nuclei at z=27
# Identified 164 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 180 nuclei at z=28
# Identified 180 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 198 nuclei at z=29
# Identified 198 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 219 nuclei at z=30
# Identified 219 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 241 nuclei at z=31
# Identified 241 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 260 nuclei at z=32
# Identified 260 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 286 nuclei at z=33
# Identified 286 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 288 nuclei at z=34
# Identified 288 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 302 nuclei at z=35
# Identified 302 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 318 nuclei at z=36
# Identified 318 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 338 nuclei at z=37
# Identified 338 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=38
# Identified 359 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=39
# Identified 355 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 371 nuclei at z=40
# Identified 371 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 379 nuclei at z=41
# Identified 379 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 393 nuclei at z=42
# Identified 393 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 403 nuclei at z=43
# Identified 403 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=44
# Identified 415 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 411 nuclei at z=45
# Identified 411 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 424 nuclei at z=46
# Identified 424 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=47
# Identified 417 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 405 nuclei at z=48
# Identified 405 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 407 nuclei at z=49
# Identified 407 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 411 nuclei at z=50
# Identified 411 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 405 nuclei at z=51
# Identified 405 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 399 nuclei at z=52
# Identified 399 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=53
# Identified 415 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 428 nuclei at z=54
# Identified 428 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 429 nuclei at z=55
# Identified 429 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 437 nuclei at z=56
# Identified 437 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 449 nuclei at z=57
# Identified 449 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 457 nuclei at z=58
# Identified 457 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 467 nuclei at z=59
# Identified 467 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 490 nuclei at z=60
# Identified 490 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 499 nuclei at z=61
# Identified 499 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 520 nuclei at z=62
# Identified 520 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 533 nuclei at z=63
# Identified 533 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 528 nuclei at z=64
# Identified 528 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 531 nuclei at z=65
# Identified 531 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 546 nuclei at z=66
# Identified 546 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 549 nuclei at z=67
# Identified 549 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 546 nuclei at z=68
# Identified 546 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 539 nuclei at z=69
# Identified 539 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 559 nuclei at z=70
# Identified 559 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 555 nuclei at z=71
# Identified 555 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 562 nuclei at z=72
# Identified 562 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=73
# Identified 578 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 572 nuclei at z=74
# Identified 572 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 576 nuclei at z=75
# Identified 576 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=76
# Identified 578 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 584 nuclei at z=77
# Identified 584 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 589 nuclei at z=78
# Identified 589 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 596 nuclei at z=79
# Identified 596 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 607 nuclei at z=80
# Identified 607 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 607 nuclei at z=81
# Identified 607 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 605 nuclei at z=82
# Identified 605 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 596 nuclei at z=83
# Identified 596 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 602 nuclei at z=84
# Identified 602 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=85
# Identified 578 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 585 nuclei at z=86
# Identified 585 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 586 nuclei at z=87
# Identified 586 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 587 nuclei at z=88
# Identified 587 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 584 nuclei at z=89
# Identified 584 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 568 nuclei at z=90
# Identified 568 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 558 nuclei at z=91
# Identified 558 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 565 nuclei at z=92
# Identified 565 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=93
# Identified 551 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 534 nuclei at z=94
# Identified 534 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=95
# Identified 550 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 587 nuclei at z=96
# Identified 587 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 593 nuclei at z=97
# Identified 593 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 589 nuclei at z=98
# Identified 589 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 619 nuclei at z=99
# Identified 619 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 635 nuclei at z=100
# Identified 635 nuclei
# Z=101 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 652 nuclei at z=101
# Identified 652 nuclei
# Z=102 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 652 nuclei at z=102
# Identified 652 nuclei
# Z=103 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 643 nuclei at z=103
# Identified 643 nuclei
# Z=104 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 662 nuclei at z=104
# Identified 662 nuclei
# Z=105 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 668 nuclei at z=105
# Identified 668 nuclei
# Z=106 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 663 nuclei at z=106
# Identified 663 nuclei
# Z=107 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 680 nuclei at z=107
# Identified 680 nuclei
# Z=108 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 679 nuclei at z=108
# Identified 679 nuclei
# Z=109 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 716 nuclei at z=109
# Identified 716 nuclei
# Z=110 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 740 nuclei at z=110
# Identified 740 nuclei
# Z=111 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 737 nuclei at z=111
# Identified 737 nuclei
# Z=112 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 718 nuclei at z=112
# Identified 718 nuclei
# Z=113 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 713 nuclei at z=113
# Identified 713 nuclei
# Z=114 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 720 nuclei at z=114
# Identified 720 nuclei
# Z=115 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=249
# Identified 727 nuclei at z=115
# Identified 727 nuclei
# Z=116 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 707 nuclei at z=116
# Identified 707 nuclei
# Z=117 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 695 nuclei at z=117
# Identified 695 nuclei
# Z=118 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 704 nuclei at z=118
# Identified 704 nuclei
# Z=119 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 705 nuclei at z=119
# Identified 705 nuclei
# Z=120 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 693 nuclei at z=120
# Identified 693 nuclei
# Z=121 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 701 nuclei at z=121
# Identified 701 nuclei
# Z=122 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 706 nuclei at z=122
# Identified 706 nuclei
# Z=123 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 687 nuclei at z=123
# Identified 687 nuclei
# Z=124 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=247
# Identified 698 nuclei at z=124
# Identified 698 nuclei
# Z=125 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 699 nuclei at z=125
# Identified 699 nuclei
# Z=126 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 695 nuclei at z=126
# Identified 695 nuclei
# Z=127 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=237
# Identified 673 nuclei at z=127
# Identified 673 nuclei
# Z=128 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=227
# Identified 650 nuclei at z=128
# Identified 650 nuclei
# Z=129 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=234
# Identified 646 nuclei at z=129
# Identified 646 nuclei
# Z=130 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 646 nuclei at z=130
# Identified 646 nuclei
# Z=131 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 604 nuclei at z=131
# Identified 604 nuclei
# Z=132 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=230
# Identified 596 nuclei at z=132
# Identified 596 nuclei
# Z=133 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=230
# Identified 599 nuclei at z=133
# Identified 599 nuclei
# Z=134 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=225
# Identified 579 nuclei at z=134
# Identified 579 nuclei
# Z=135 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 546 nuclei at z=135
# Identified 546 nuclei
# Z=136 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 537 nuclei at z=136
# Identified 537 nuclei
# Z=137 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=229
# Identified 528 nuclei at z=137
# Identified 528 nuclei
# Z=138 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 513 nuclei at z=138
# Identified 513 nuclei
# Z=139 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=205
# Identified 507 nuclei at z=139
# Identified 507 nuclei
# Z=140 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 486 nuclei at z=140
# Identified 486 nuclei
# Z=141 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 490 nuclei at z=141
# Identified 490 nuclei
# Z=142 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=204
# Identified 462 nuclei at z=142
# Identified 462 nuclei
# Z=143 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=232
# Identified 450 nuclei at z=143
# Identified 450 nuclei
# Z=144 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=202
# Identified 424 nuclei at z=144
# Identified 424 nuclei
# Z=145 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# Identified 420 nuclei at z=145
# Identified 420 nuclei
# Z=146 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=218
# Identified 403 nuclei at z=146
# Identified 403 nuclei
# Z=147 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=205
# Identified 386 nuclei at z=147
# Identified 386 nuclei
# Z=148 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=203
# Identified 369 nuclei at z=148
# Identified 369 nuclei
# Z=149 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=196
# Identified 362 nuclei at z=149
# Identified 362 nuclei
# Z=150 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=196
# Identified 336 nuclei at z=150
# Identified 336 nuclei
# Z=151 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 313 nuclei at z=151
# Identified 313 nuclei
# Z=152 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=182
# Identified 308 nuclei at z=152
# Identified 308 nuclei
# Z=153 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=213
# Identified 288 nuclei at z=153
# Identified 288 nuclei
# Z=154 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 287 nuclei at z=154
# Identified 287 nuclei
# Z=155 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=198
# Identified 268 nuclei at z=155
# Identified 268 nuclei
# Z=156 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=200
# Identified 257 nuclei at z=156
# Identified 257 nuclei
# Z=157 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 241 nuclei at z=157
# Identified 241 nuclei
# Z=158 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=181
# Identified 215 nuclei at z=158
# Identified 215 nuclei
# Z=159 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 202 nuclei at z=159
# Identified 202 nuclei
# Z=160 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=175
# Identified 186 nuclei at z=160
# Identified 186 nuclei
# Z=161 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=178
# Identified 173 nuclei at z=161
# Identified 173 nuclei
# Z=162 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=155
# Identified 152 nuclei at z=162
# Identified 152 nuclei
# Z=163 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=182
# Identified 144 nuclei at z=163
# Identified 144 nuclei
# Z=164 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=169
# Identified 135 nuclei at z=164
# Identified 135 nuclei
# Z=165 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=188
# Identified 124 nuclei at z=165
# Identified 124 nuclei
# Z=166 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 107 nuclei at z=166
# Identified 107 nuclei
# Z=167 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=188
# Identified 82 nuclei at z=167
# Identified 82 nuclei
# Z=168 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 77 nuclei at z=168
# Identified 77 nuclei
# Z=169 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=168
# Identified 55 nuclei at z=169
# Identified 55 nuclei
# Z=170 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 42 nuclei at z=170
# Identified 42 nuclei
# Z=171 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=154
# Identified 27 nuclei at z=171
# Identified 27 nuclei
# Z=172 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=145
# Identified 14 nuclei at z=172
# Identified 14 nuclei
# Z=173 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=188
# Identified 5 nuclei at z=173
# Identified 5 nuclei
# Z=174 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=157
# Identified 3 nuclei at z=174
# Identified 3 nuclei
# Z=175 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=137
# Identified 6 nuclei at z=175
# Identified 6 nuclei
# Z=176 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 6 nuclei at z=176
# Identified 6 nuclei
# Z=177 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=181
# Identified 5 nuclei at z=177
# Identified 5 nuclei
# Z=178 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=158
# Identified 3 nuclei at z=178
# Identified 3 nuclei
# Z=179 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=177
# Identified 5 nuclei at z=179
# Identified 5 nuclei
# Z=180 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=149
# Identified 5 nuclei at z=180
# Identified 5 nuclei
# Z=181 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# Identified 4 nuclei at z=181
# Identified 4 nuclei
# Z=182 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=200
# Identified 0 nuclei at z=182
# Identified 0 nuclei
# Z=183 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=157
# Identified 0 nuclei at z=183
# Identified 0 nuclei
# Z=184 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# 2025-04-07 08:44:46,148 [INFO] No cell pixels found.
# Identified 0 nuclei at z=184
# Identified 0 nuclei
# Z=185 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# 2025-04-07 08:44:46,582 [INFO] No cell pixels found.
# Identified 0 nuclei at z=185
# Identified 0 nuclei
# Z=186 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# 2025-04-07 08:44:47,045 [INFO] No cell pixels found.
# Identified 0 nuclei at z=186
# Identified 0 nuclei
# Z=187 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=178
# 2025-04-07 08:44:47,475 [INFO] No cell pixels found.
# Identified 0 nuclei at z=187
# Identified 0 nuclei
# Z=188 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=139
# 2025-04-07 08:44:47,921 [INFO] No cell pixels found.
# Identified 0 nuclei at z=188
# Identified 0 nuclei
# Z=189 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=194
# 2025-04-07 08:44:48,346 [INFO] No cell pixels found.
# Identified 0 nuclei at z=189
# Identified 0 nuclei
# Z=190 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# 2025-04-07 08:44:48,785 [INFO] No cell pixels found.
# Identified 0 nuclei at z=190
# Identified 0 nuclei
# Z=191 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=147
# 2025-04-07 08:44:49,232 [INFO] No cell pixels found.
# Identified 0 nuclei at z=191
# Identified 0 nuclei
# Z=192 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=144
# 2025-04-07 08:44:49,681 [INFO] No cell pixels found.
# Identified 0 nuclei at z=192
# Identified 0 nuclei
# Z=193 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=142
# 2025-04-07 08:44:50,121 [INFO] No cell pixels found.
# Identified 0 nuclei at z=193
# Identified 0 nuclei
# Z=194 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=164
# 2025-04-07 08:44:50,576 [INFO] No cell pixels found.
# Identified 0 nuclei at z=194
# Identified 0 nuclei
# Z=195 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=170
# 2025-04-07 08:44:51,002 [INFO] No cell pixels found.
# Identified 0 nuclei at z=195
# Identified 0 nuclei
# Z=196 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# 2025-04-07 08:44:51,444 [INFO] No cell pixels found.
# Identified 0 nuclei at z=196
# Identified 0 nuclei
# Z=197 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=159
# 2025-04-07 08:44:51,872 [INFO] No cell pixels found.
# Identified 0 nuclei at z=197
# Identified 0 nuclei
# Z=198 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# Identified 0 nuclei at z=198
# Identified 0 nuclei
# Z=199 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=137
# Identified 1 nuclei at z=199
# Identified 1 nuclei
# Z=200 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=128
# Identified 0 nuclei at z=200
# Identified 0 nuclei
# Z=201 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=112
# Identified 0 nuclei at z=201
# Identified 0 nuclei
# ROIs saved to ../results/20250307 B1 P14 U34-B3-546 Chymotrypsin-B2-647 DAPI/20250307 B1 Sample 5 Stack_rois.npy
# Processing 20250307 B1 Sample 4 Stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 0.5, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (202, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 202
# Z resolution: 0.5 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:38,090 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:38,516 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:38,964 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:39,404 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:39,865 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:40,298 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:40,751 [INFO] No cell pixels found.
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:41,183 [INFO] No cell pixels found.
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:41,636 [INFO] No cell pixels found.
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:42,065 [INFO] No cell pixels found.
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:42,517 [INFO] No cell pixels found.
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:42,950 [INFO] No cell pixels found.
# Identified 0 nuclei at z=11
# Identified 0 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 08:45:43,402 [INFO] No cell pixels found.
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=13
# Identified 1 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=15
# Identified 0 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=16
# Identified 0 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=17
# Identified 0 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=18
# Identified 0 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=19
# Identified 6 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 15 nuclei at z=20
# Identified 15 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 20 nuclei at z=21
# Identified 20 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 42 nuclei at z=22
# Identified 42 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 57 nuclei at z=23
# Identified 57 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 72 nuclei at z=24
# Identified 72 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 89 nuclei at z=25
# Identified 89 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 106 nuclei at z=26
# Identified 106 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 116 nuclei at z=27
# Identified 116 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 122 nuclei at z=28
# Identified 122 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 134 nuclei at z=29
# Identified 134 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 177 nuclei at z=30
# Identified 177 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 206 nuclei at z=31
# Identified 206 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 225 nuclei at z=32
# Identified 225 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 248 nuclei at z=33
# Identified 248 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 273 nuclei at z=34
# Identified 273 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 302 nuclei at z=35
# Identified 302 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 315 nuclei at z=36
# Identified 315 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 324 nuclei at z=37
# Identified 324 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=38
# Identified 355 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=39
# Identified 359 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 360 nuclei at z=40
# Identified 360 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 371 nuclei at z=41
# Identified 371 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=42
# Identified 384 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 389 nuclei at z=43
# Identified 389 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 401 nuclei at z=44
# Identified 401 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 432 nuclei at z=45
# Identified 432 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 454 nuclei at z=46
# Identified 454 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 483 nuclei at z=47
# Identified 483 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 505 nuclei at z=48
# Identified 505 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 529 nuclei at z=49
# Identified 529 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=50
# Identified 550 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 560 nuclei at z=51
# Identified 560 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 571 nuclei at z=52
# Identified 571 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 588 nuclei at z=53
# Identified 588 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 588 nuclei at z=54
# Identified 588 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 608 nuclei at z=55
# Identified 608 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 620 nuclei at z=56
# Identified 620 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 631 nuclei at z=57
# Identified 631 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=58
# Identified 633 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 646 nuclei at z=59
# Identified 646 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 656 nuclei at z=60
# Identified 656 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 680 nuclei at z=61
# Identified 680 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 688 nuclei at z=62
# Identified 688 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 711 nuclei at z=63
# Identified 711 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 717 nuclei at z=64
# Identified 717 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 704 nuclei at z=65
# Identified 704 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 704 nuclei at z=66
# Identified 704 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 705 nuclei at z=67
# Identified 705 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 715 nuclei at z=68
# Identified 715 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 696 nuclei at z=69
# Identified 696 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 720 nuclei at z=70
# Identified 720 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 698 nuclei at z=71
# Identified 698 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 716 nuclei at z=72
# Identified 716 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 732 nuclei at z=73
# Identified 732 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 731 nuclei at z=74
# Identified 731 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 729 nuclei at z=75
# Identified 729 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 715 nuclei at z=76
# Identified 715 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 703 nuclei at z=77
# Identified 703 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 708 nuclei at z=78
# Identified 708 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 697 nuclei at z=79
# Identified 697 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 701 nuclei at z=80
# Identified 701 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 688 nuclei at z=81
# Identified 688 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 683 nuclei at z=82
# Identified 683 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 690 nuclei at z=83
# Identified 690 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 681 nuclei at z=84
# Identified 681 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 658 nuclei at z=85
# Identified 658 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 646 nuclei at z=86
# Identified 646 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=87
# Identified 633 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 656 nuclei at z=88
# Identified 656 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 637 nuclei at z=89
# Identified 637 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=90
# Identified 633 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 652 nuclei at z=91
# Identified 652 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 656 nuclei at z=92
# Identified 656 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 619 nuclei at z=93
# Identified 619 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 596 nuclei at z=94
# Identified 596 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 572 nuclei at z=95
# Identified 572 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 573 nuclei at z=96
# Identified 573 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 548 nuclei at z=97
# Identified 548 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=251
# Identified 546 nuclei at z=98
# Identified 546 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=242
# Identified 533 nuclei at z=99
# Identified 533 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 534 nuclei at z=100
# Identified 534 nuclei
# Z=101 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 556 nuclei at z=101
# Identified 556 nuclei
# Z=102 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 574 nuclei at z=102
# Identified 574 nuclei
# Z=103 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 568 nuclei at z=103
# Identified 568 nuclei
# Z=104 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 565 nuclei at z=104
# Identified 565 nuclei
# Z=105 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=105
# Identified 551 nuclei
# Z=106 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 553 nuclei at z=106
# Identified 553 nuclei
# Z=107 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 547 nuclei at z=107
# Identified 547 nuclei
# Z=108 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 555 nuclei at z=108
# Identified 555 nuclei
# Z=109 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 580 nuclei at z=109
# Identified 580 nuclei
# Z=110 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=239
# Identified 587 nuclei at z=110
# Identified 587 nuclei
# Z=111 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=247
# Identified 606 nuclei at z=111
# Identified 606 nuclei
# Z=112 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 609 nuclei at z=112
# Identified 609 nuclei
# Z=113 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 604 nuclei at z=113
# Identified 604 nuclei
# Z=114 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 608 nuclei at z=114
# Identified 608 nuclei
# Z=115 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 599 nuclei at z=115
# Identified 599 nuclei
# Z=116 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=249
# Identified 584 nuclei at z=116
# Identified 584 nuclei
# Z=117 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 582 nuclei at z=117
# Identified 582 nuclei
# Z=118 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=248
# Identified 603 nuclei at z=118
# Identified 603 nuclei
# Z=119 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=242
# Identified 619 nuclei at z=119
# Identified 619 nuclei
# Z=120 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=227
# Identified 618 nuclei at z=120
# Identified 618 nuclei
# Z=121 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 610 nuclei at z=121
# Identified 610 nuclei
# Z=122 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=236
# Identified 587 nuclei at z=122
# Identified 587 nuclei
# Z=123 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=248
# Identified 594 nuclei at z=123
# Identified 594 nuclei
# Z=124 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 574 nuclei at z=124
# Identified 574 nuclei
# Z=125 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 575 nuclei at z=125
# Identified 575 nuclei
# Z=126 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=219
# Identified 586 nuclei at z=126
# Identified 586 nuclei
# Z=127 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 611 nuclei at z=127
# Identified 611 nuclei
# Z=128 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 615 nuclei at z=128
# Identified 615 nuclei
# Z=129 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 620 nuclei at z=129
# Identified 620 nuclei
# Z=130 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 611 nuclei at z=130
# Identified 611 nuclei
# Z=131 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=238
# Identified 612 nuclei at z=131
# Identified 612 nuclei
# Z=132 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 608 nuclei at z=132
# Identified 608 nuclei
# Z=133 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 592 nuclei at z=133
# Identified 592 nuclei
# Z=134 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 591 nuclei at z=134
# Identified 591 nuclei
# Z=135 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=220
# Identified 594 nuclei at z=135
# Identified 594 nuclei
# Z=136 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# Identified 609 nuclei at z=136
# Identified 609 nuclei
# Z=137 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=219
# Identified 621 nuclei at z=137
# Identified 621 nuclei
# Z=138 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=208
# Identified 587 nuclei at z=138
# Identified 587 nuclei
# Z=139 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 614 nuclei at z=139
# Identified 614 nuclei
# Z=140 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=235
# Identified 630 nuclei at z=140
# Identified 630 nuclei
# Z=141 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 624 nuclei at z=141
# Identified 624 nuclei
# Z=142 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=212
# Identified 618 nuclei at z=142
# Identified 618 nuclei
# Z=143 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=185
# Identified 602 nuclei at z=143
# Identified 602 nuclei
# Z=144 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=208
# Identified 609 nuclei at z=144
# Identified 609 nuclei
# Z=145 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=207
# Identified 612 nuclei at z=145
# Identified 612 nuclei
# Z=146 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=204
# Identified 613 nuclei at z=146
# Identified 613 nuclei
# Z=147 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 610 nuclei at z=147
# Identified 610 nuclei
# Z=148 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=192
# Identified 608 nuclei at z=148
# Identified 608 nuclei
# Z=149 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=196
# Identified 590 nuclei at z=149
# Identified 590 nuclei
# Z=150 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 582 nuclei at z=150
# Identified 582 nuclei
# Z=151 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=201
# Identified 545 nuclei at z=151
# Identified 545 nuclei
# Z=152 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=206
# Identified 529 nuclei at z=152
# Identified 529 nuclei
# Z=153 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 519 nuclei at z=153
# Identified 519 nuclei
# Z=154 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=195
# Identified 498 nuclei at z=154
# Identified 498 nuclei
# Z=155 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 453 nuclei at z=155
# Identified 453 nuclei
# Z=156 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=198
# Identified 436 nuclei at z=156
# Identified 436 nuclei
# Z=157 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=214
# Identified 434 nuclei at z=157
# Identified 434 nuclei
# Z=158 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 403 nuclei at z=158
# Identified 403 nuclei
# Z=159 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 385 nuclei at z=159
# Identified 385 nuclei
# Z=160 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=178
# Identified 356 nuclei at z=160
# Identified 356 nuclei
# Z=161 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 323 nuclei at z=161
# Identified 323 nuclei
# Z=162 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=199
# Identified 297 nuclei at z=162
# Identified 297 nuclei
# Z=163 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=191
# Identified 279 nuclei at z=163
# Identified 279 nuclei
# Z=164 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 254 nuclei at z=164
# Identified 254 nuclei
# Z=165 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 229 nuclei at z=165
# Identified 229 nuclei
# Z=166 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=152
# Identified 186 nuclei at z=166
# Identified 186 nuclei
# Z=167 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=164
# Identified 151 nuclei at z=167
# Identified 151 nuclei
# Z=168 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=151
# Identified 127 nuclei at z=168
# Identified 127 nuclei
# Z=169 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=158
# Identified 105 nuclei at z=169
# Identified 105 nuclei
# Z=170 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=180
# Identified 90 nuclei at z=170
# Identified 90 nuclei
# Z=171 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=175
# Identified 63 nuclei at z=171
# Identified 63 nuclei
# Z=172 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 47 nuclei at z=172
# Identified 47 nuclei
# Z=173 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=159
# Identified 35 nuclei at z=173
# Identified 35 nuclei
# Z=174 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=195
# Identified 24 nuclei at z=174
# Identified 24 nuclei
# Z=175 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=219
# Identified 22 nuclei at z=175
# Identified 22 nuclei
# Z=176 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=152
# Identified 15 nuclei at z=176
# Identified 15 nuclei
# Z=177 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=151
# Identified 15 nuclei at z=177
# Identified 15 nuclei
# Z=178 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=207
# Identified 18 nuclei at z=178
# Identified 18 nuclei
# Z=179 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=146
# Identified 15 nuclei at z=179
# Identified 15 nuclei
# Z=180 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=159
# Identified 13 nuclei at z=180
# Identified 13 nuclei
# Z=181 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# Identified 8 nuclei at z=181
# Identified 8 nuclei
# Z=182 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 4 nuclei at z=182
# Identified 4 nuclei
# Z=183 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 1 nuclei at z=183
# Identified 1 nuclei
# Z=184 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=171
# 2025-04-07 08:48:08,690 [INFO] No cell pixels found.
# Identified 0 nuclei at z=184
# Identified 0 nuclei
# Z=185 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=146
# 2025-04-07 08:48:09,334 [INFO] No cell pixels found.
# Identified 0 nuclei at z=185
# Identified 0 nuclei
# Z=186 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=172
# 2025-04-07 08:48:09,944 [INFO] No cell pixels found.
# Identified 0 nuclei at z=186
# Identified 0 nuclei
# Z=187 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=166
# 2025-04-07 08:48:10,533 [INFO] No cell pixels found.
# Identified 0 nuclei at z=187
# Identified 0 nuclei
# Z=188 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=188
# 2025-04-07 08:48:11,142 [INFO] No cell pixels found.
# Identified 0 nuclei at z=188
# Identified 0 nuclei
# Z=189 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=217
# 2025-04-07 08:48:11,726 [INFO] No cell pixels found.
# Identified 0 nuclei at z=189
# Identified 0 nuclei
# Z=190 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=164
# 2025-04-07 08:48:12,316 [INFO] No cell pixels found.
# Identified 0 nuclei at z=190
# Identified 0 nuclei
# Z=191 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=176
# 2025-04-07 08:48:12,874 [INFO] No cell pixels found.
# Identified 0 nuclei at z=191
# Identified 0 nuclei
# Z=192 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=182
# 2025-04-07 08:48:13,445 [INFO] No cell pixels found.
# Identified 0 nuclei at z=192
# Identified 0 nuclei
# Z=193 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=154
# 2025-04-07 08:48:14,006 [INFO] No cell pixels found.
# Identified 0 nuclei at z=193
# Identified 0 nuclei
# Z=194 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=153
# 2025-04-07 08:48:14,561 [INFO] No cell pixels found.
# Identified 0 nuclei at z=194
# Identified 0 nuclei
# Z=195 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# 2025-04-07 08:48:15,122 [INFO] No cell pixels found.
# Identified 0 nuclei at z=195
# Identified 0 nuclei
# Z=196 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=142
# 2025-04-07 08:48:15,671 [INFO] No cell pixels found.
# Identified 0 nuclei at z=196
# Identified 0 nuclei
# Z=197 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=149
# 2025-04-07 08:48:16,194 [INFO] No cell pixels found.
# Identified 0 nuclei at z=197
# Identified 0 nuclei
# Z=198 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=168
# Error at z=198: tuple index out of range
# Z=199 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=132
# 2025-04-07 08:48:17,151 [INFO] No cell pixels found.
# Identified 0 nuclei at z=199
# Identified 0 nuclei
# ...
# Identified 443 nuclei at z=27
# Identified 443 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 457 nuclei at z=28
# Identified 457 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 399 nuclei at z=29
# Identified 399 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# Identified 426 nuclei at z=30
# Identified 426 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=180
# Identified 408 nuclei at z=31
# Identified 408 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=135
# Identified 398 nuclei at z=32
# Identified 398 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=139
# Identified 378 nuclei at z=33
# Identified 378 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 399 nuclei at z=34
# Identified 399 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=158
# Identified 359 nuclei at z=35
# Identified 359 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=142
# Identified 351 nuclei at z=36
# Identified 351 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=125
# Identified 308 nuclei at z=37
# Identified 308 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# Identified 245 nuclei at z=38
# Identified 245 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=138
# Identified 245 nuclei at z=39
# Identified 245 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 287 nuclei at z=40
# Identified 287 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=115
# Identified 322 nuclei at z=41
# Identified 322 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=185
# Identified 348 nuclei at z=42
# Identified 348 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=123
# Identified 363 nuclei at z=43
# Identified 363 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# Identified 357 nuclei at z=44
# Identified 357 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=119
# Identified 344 nuclei at z=45
# Identified 344 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=135
# Identified 382 nuclei at z=46
# Identified 382 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=127
# Identified 352 nuclei at z=47
# Identified 352 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# Identified 388 nuclei at z=48
# Identified 388 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=115
# Identified 404 nuclei at z=49
# Identified 404 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=132
# Identified 382 nuclei at z=50
# Identified 382 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=120
# Identified 384 nuclei at z=51
# Identified 384 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=153
# Identified 383 nuclei at z=52
# Identified 383 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=155
# Identified 390 nuclei at z=53
# Identified 390 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 380 nuclei at z=54
# Identified 380 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=119
# Identified 386 nuclei at z=55
# Identified 386 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=107
# Identified 399 nuclei at z=56
# Identified 399 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=161
# Identified 376 nuclei at z=57
# Identified 376 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=116
# Identified 356 nuclei at z=58
# Identified 356 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 364 nuclei at z=59
# Identified 364 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=156
# Identified 364 nuclei at z=60
# Identified 364 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=143
# Identified 390 nuclei at z=61
# Identified 390 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=133
# Identified 374 nuclei at z=62
# Identified 374 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=117
# Identified 361 nuclei at z=63
# Identified 361 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=190
# Identified 335 nuclei at z=64
# Identified 335 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 323 nuclei at z=65
# Identified 323 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=117
# Identified 319 nuclei at z=66
# Identified 319 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=121
# Identified 262 nuclei at z=67
# Identified 262 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=100
# Identified 270 nuclei at z=68
# Identified 270 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=100
# Identified 231 nuclei at z=69
# Identified 231 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=110
# Identified 214 nuclei at z=70
# Identified 214 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# Identified 148 nuclei at z=71
# Identified 148 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 124 nuclei at z=72
# Identified 124 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=113
# Identified 99 nuclei at z=73
# Identified 99 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=131
# Identified 73 nuclei at z=74
# Identified 73 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=112
# Identified 42 nuclei at z=75
# Identified 42 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 21 nuclei at z=76
# Identified 21 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=122
# Identified 6 nuclei at z=77
# Identified 6 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=110
# Identified 0 nuclei at z=78
# Identified 0 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=137
# 2025-04-07 09:49:57,652 [INFO] No cell pixels found.
# Identified 0 nuclei at z=79
# Identified 0 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=201
# 2025-04-07 09:49:58,112 [INFO] No cell pixels found.
# Identified 0 nuclei at z=80
# Identified 0 nuclei
# ROIs saved to ../results/20250328 3 P14 Lnc3-b3-488 L16-b2-594 Lnc2-b5-647 DAPI/20250328 3 L16lnc sample 3_rois.npy
# Processing 20250328 3 L16lnc sample 1.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2', 'AF594-T2']}
# Image shape: (81, 4, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 81
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1'), (3, 'AF594-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-04-07 09:50:18,570 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=247
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=251
# 2025-04-07 09:50:19,570 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=235
# 2025-04-07 09:50:20,037 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# 2025-04-07 09:50:20,492 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=242
# 2025-04-07 09:50:20,948 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# 2025-04-07 09:50:21,398 [INFO] No cell pixels found.
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=7
# Identified 5 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 26 nuclei at z=8
# Identified 26 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=244
# Identified 65 nuclei at z=9
# Identified 65 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 94 nuclei at z=10
# Identified 94 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 106 nuclei at z=11
# Identified 106 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=252
# Identified 129 nuclei at z=12
# Identified 129 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 159 nuclei at z=13
# Identified 159 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=235
# Identified 184 nuclei at z=14
# Identified 184 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# Identified 234 nuclei at z=15
# Identified 234 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=238
# Identified 274 nuclei at z=16
# Identified 274 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 305 nuclei at z=17
# Identified 305 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=229
# Identified 311 nuclei at z=18
# Identified 311 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=239
# Identified 319 nuclei at z=19
# Identified 319 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 327 nuclei at z=20
# Identified 327 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=247
# Identified 372 nuclei at z=21
# Identified 372 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 443 nuclei at z=22
# Identified 443 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=220
# Identified 421 nuclei at z=23
# Identified 421 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=220
# Identified 440 nuclei at z=24
# Identified 440 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 463 nuclei at z=25
# Identified 463 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 425 nuclei at z=26
# Identified 425 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=214
# Identified 452 nuclei at z=27
# Identified 452 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 465 nuclei at z=28
# Identified 465 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=205
# Identified 466 nuclei at z=29
# Identified 466 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 449 nuclei at z=30
# Identified 449 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=202
# Identified 461 nuclei at z=31
# Identified 461 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 464 nuclei at z=32
# Identified 464 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=200
# Identified 477 nuclei at z=33
# Identified 477 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=232
# Identified 470 nuclei at z=34
# Identified 470 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=229
# Identified 477 nuclei at z=35
# Identified 477 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# Identified 481 nuclei at z=36
# Identified 481 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 492 nuclei at z=37
# Identified 492 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=230
# Identified 477 nuclei at z=38
# Identified 477 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 451 nuclei at z=39
# Identified 451 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 409 nuclei at z=40
# Identified 409 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=213
# Identified 377 nuclei at z=41
# Identified 377 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 361 nuclei at z=42
# Identified 361 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 381 nuclei at z=43
# Identified 381 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 412 nuclei at z=44
# Identified 412 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 417 nuclei at z=45
# Identified 417 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 436 nuclei at z=46
# Identified 436 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=195
# Identified 442 nuclei at z=47
# Identified 442 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 430 nuclei at z=48
# Identified 430 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=191
# Identified 452 nuclei at z=49
# Identified 452 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=181
# Identified 433 nuclei at z=50
# Identified 433 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 423 nuclei at z=51
# Identified 423 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 417 nuclei at z=52
# Identified 417 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=178
# Identified 449 nuclei at z=53
# Identified 449 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=177
# Identified 474 nuclei at z=54
# Identified 474 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 497 nuclei at z=55
# Identified 497 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=244
# Identified 518 nuclei at z=56
# Identified 518 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=177
# Identified 495 nuclei at z=57
# Identified 495 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 471 nuclei at z=58
# Identified 471 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=156
# Identified 453 nuclei at z=59
# Identified 453 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=167
# Identified 464 nuclei at z=60
# Identified 464 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=175
# Identified 500 nuclei at z=61
# Identified 500 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=206
# Identified 494 nuclei at z=62
# Identified 494 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 503 nuclei at z=63
# Identified 503 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=185
# Identified 514 nuclei at z=64
# Identified 514 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=65
# Identified 504 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=169
# Identified 468 nuclei at z=66
# Identified 468 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=147
# Identified 416 nuclei at z=67
# Identified 416 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=146
# Identified 388 nuclei at z=68
# Identified 388 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=158
# Identified 370 nuclei at z=69
# Identified 370 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=157
# Identified 349 nuclei at z=70
# Identified 349 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=148
# Identified 321 nuclei at z=71
# Identified 321 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=169
# Identified 260 nuclei at z=72
# Identified 260 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=146
# Identified 227 nuclei at z=73
# Identified 227 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 179 nuclei at z=74
# Identified 179 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=135
# Identified 144 nuclei at z=75
# Identified 144 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 82 nuclei at z=76
# Identified 82 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=212
# Identified 32 nuclei at z=77
# Identified 32 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 2 nuclei at z=78
# Identified 2 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=146
# Identified 0 nuclei at z=79
# Identified 0 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=138
# 2025-04-07 09:51:15,524 [INFO] No cell pixels found.
# Identified 0 nuclei at z=80
# Identified 0 nuclei
# ROIs saved to ../results/20250328 3 P14 Lnc3-b3-488 L16-b2-594 Lnc2-b5-647 DAPI/20250328 3 L16lnc sample 1_rois.npy
