# %% [markdown]
# # 2. Run Nucleus Segmentation Model

# %% [markdown]
# gg-napari-env

# %%
from napari_czifile2 import napari_get_reader
from cellpose import models, core
from cellpose.io import logger_setup
import torch 
import numpy as np
import numpy as np
import os 
from plotting import * 
import warnings
warnings.filterwarnings("ignore")
use_GPU = core.use_gpu()
torch.cuda.empty_cache()
print('>>> GPU activated? %d'%use_GPU)
logger_setup()
# Out:
# Initializing plotting package
# >>> GPU activated? 1
# 2025-08-15 12:58:17,492 [INFO] WRITING LOG OUTPUT TO /home/tracking/.cellpose/run.log
# 2025-08-15 12:58:17,493 [INFO]
# cellpose version: 	3.1.0
# platform:       	linux
# python version: 	3.12.8
# torch version:  	2.5.1+cu124
# (<Logger cellpose.io (INFO)>, PosixPath('/home/tracking/.cellpose/run.log'))

# %%
raw_data_dirs = os.listdir('../../../RNA-FISH-raw-data/')
raw_data_dirs
# Out:
# ['20250508 P14 T 9E89-b1-546 9E99-B2-647 DAPI',
#  '20250307 B1 P14 U34-B3-546 Chymotrypsin-B2-647 DAPI',
#  '20250328 1 P14 T79-intergenic-b2-647 T79-exonic-b1-546 DAPI',
#  '20250325 6 P14 9E198-B3-488 9E197-B1-546 9E196-B2-647 DAPI',
#  '20250328 5 P14 LOC603-b3-488 9E108-b1-546 9E116-b2-647 DAPI',
#  '20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI',
#  '20250508 P14 T 9E99-b2-594 LOC105286072-B5-647 DAPI',
#  '20250701 D P14 P1-B1-546 P2-B2-647 P1-antisense-B3-488 DAPI',
#  '20250808 E P14 P1-b1-546 Y1-b3-488 Y1-P1-Intergenic-b4-647 DAPI',
#  '20250701 E P14 Y1-B3-488 P1-B1-546 P2-B2-647 DAPI',
#  '20250328 2 P14 R2-b3-488 Q1-b1-546 Lnc6-b2-647 DAPI',
#  '20250325 5 P14 G1-b1-546 lnc7-B2-647 DAPI',
#  '20250701 B P14 E10-B1-546 E11-B2-647 DAPI',
#  '20250523 C P14 T U54-647 Lnc4-546 DAPI',
#  '20250523 A P14 T 9E213-546 9E214-488 Intergenic-647 DAPI',
#  '20250325 4 P14 U34-B3-488 lnc4-B1-546 U21-B5-647 DAPI',
#  '20250813 B P14 U34-B3-488 Lnc4-B1-546 U21-B5-647 DAPI',
#  '20250328 3 P14 Lnc3-b3-488 L16-b2-594 Lnc2-b5-647 DAPI',
#  '20250701 A P14 9E118-EXONS-B1-546 9E118-INTRONS-B2-647 9E129-B3-488 DAPI',
#  '20250813 D P14 9E118-exons-B1-546 9E118-introns-B2-647 9E129-B3-488 DAPI',
#  '20250813 A P14 P1-B1-546 P2-B2-647 P1-antisense-B3-488 DAPI',
#  'temp_not_for_paper',
#  '20250701 C P14 9E184-B1-546 9E185-186-B2-647',
#  'tifs',
#  '20250328 4 P14 9E129-b3-488 LOC104-b1-546 9E116-b2-647 DAPI',
#  '20250701 F P14 U34-b3-546 Orco-b4-647 DAPI',
#  '20250808 D P14 E10-b1-546 E11-b2-647 E10-E11-Intergenic-b3-488 DAPI',
#  '20250523 B P14 T 9E88-546 Lnc-647 DAPI']

# %%
input = '20250701 C'
input = [d for d in raw_data_dirs if input in d][0]
print(f'Using {input} as input directory')
input_dir = f'../../../RNA-FISH-raw-data/{input}/'
assert os.path.exists(input_dir), 'Input directory does not exist'
czi_files = [f for f in os.listdir(input_dir) if f.endswith('.czi')]
print(f"Found {len(czi_files)} czi files in {input_dir}")
print(czi_files)
# Out:
# Using 20250701 C P14 9E184-B1-546 9E185-186-B2-647 as input directory
# Found 7 czi files in ../../../RNA-FISH-raw-data/20250701 C P14 9E184-B1-546 9E185-186-B2-647/
# ['20250701 C sample 6 stack.czi', '20250701 C sample 7 stack.czi', '20250701 C sample 4 stack.czi', '20250701 C sample 5 stack.czi', '20250701 C sample 2 stack.czi', '20250701 C sample 3 stack.czi', '20250701 C sample 1 stack.czi']

# %%
# Load trained model 
model_path = '../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs'
model = models.CellposeModel(gpu=True, pretrained_model=model_path)
# Out:
# 2025-08-15 12:58:17,548 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-15 12:58:17,550 [INFO] >>>> using GPU (CUDA)
# 2025-08-15 12:58:17,690 [INFO] >>>> loading model ../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs
# 2025-08-15 12:58:18,147 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-15 12:58:18,149 [INFO] >>>> model diam_labels =  29.464 (mean diameter of training ROIs)

# %%
results_dir = f'../results/{input}'
if not os.path.exists(results_dir):
    os.makedirs(results_dir)
    
for f in czi_files[:]:
    print(f"Processing {f}")
    file_path = os.path.join(input_dir, f)
    reader = napari_get_reader(file_path)
    if reader is not None:
        layer_data = reader(file_path)
        image_data, metadata, layer_type = layer_data[0]
        # Remove singleton dimension 
        image_data = np.squeeze(image_data)  
        print("Metadata:", metadata)
        print("Image shape:", image_data.shape)  
        print(f"Number of NaN pixels: {np.sum(np.isnan(image_data))}")

        pixel_x = metadata['scale'][2]
        print(f"Pixel size: {pixel_x} um")

        xy_resolution = image_data.shape[-1] 
        print(f"XY resolution: {xy_resolution} pixels")

        nucleus_diameter = 3 / pixel_x
        print(f"Nucleus diameter: {nucleus_diameter} pixels") 
        
        z_slices = image_data.shape[0]
        print(f"Z slices: {z_slices}")

        z_um = metadata['scale'][1]
        print(f"Z resolution: {z_um} um")

        dapi_index = metadata['name'].index([name for name in metadata['name'] if 'DAPI' in name][0])
        print(f"DAPI channel index: {dapi_index}")

        non_dapi_channels = [(i, metadata['name'][i]) for i in range(len(metadata['name'])) if i != dapi_index]
        print(f"Non-DAPI channels: {non_dapi_channels}")

        all_rois = np.zeros_like(image_data[:, dapi_index, :, :], dtype=np.uint16)
        for z in range(z_slices):
            image_data_z = image_data[z, dapi_index, :, :]
            print(f"Z={z} | shape={image_data_z.shape} | dtype={image_data_z.dtype} | min={image_data_z.min()} | max={image_data_z.max()}")
            try:
                rois, flows, styles = model.eval(image_data_z, diameter=nucleus_diameter)
                print(f"Identified {rois.max()} nuclei at z={z}")
            except Exception as e:
                print(f"Error at z={z}: {e}")
                continue
            print(f"Identified {rois.max()} nuclei")
            all_rois[z, :, :] = rois

        # Save the masks to a file 
        all_rois_path = os.path.join(results_dir, f.replace('.czi', f'_rois.npy'))
        np.save(all_rois_path, all_rois)
        print(f"ROIs saved to {all_rois_path}")
# Out:
# Processing 20250701 C sample 6 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (101, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 101
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=64
# 2025-07-02 17:52:24,482 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=60
# 2025-07-02 17:52:25,164 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=69
# 2025-07-02 17:52:25,825 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=83
# 2025-07-02 17:52:26,529 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=101
# 2025-07-02 17:52:27,194 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=110
# 2025-07-02 17:52:27,893 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=117
# 2025-07-02 17:52:28,539 [INFO] No cell pixels found.
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=141
# 2025-07-02 17:52:29,184 [INFO] No cell pixels found.
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=188
# 2025-07-02 17:52:29,800 [INFO] No cell pixels found.
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=214
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=11
# Identified 0 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:33,442 [INFO] No cell pixels found.
# Identified 0 nuclei at z=13
# Identified 0 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:33,958 [INFO] No cell pixels found.
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:34,487 [INFO] No cell pixels found.
# Identified 0 nuclei at z=15
# Identified 0 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:34,975 [INFO] No cell pixels found.
# Identified 0 nuclei at z=16
# Identified 0 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:35,465 [INFO] No cell pixels found.
# Identified 0 nuclei at z=17
# Identified 0 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:35,948 [INFO] No cell pixels found.
# Identified 0 nuclei at z=18
# Identified 0 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:36,440 [INFO] No cell pixels found.
# Identified 0 nuclei at z=19
# Identified 0 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:36,942 [INFO] No cell pixels found.
# Identified 0 nuclei at z=20
# Identified 0 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:37,430 [INFO] No cell pixels found.
# Identified 0 nuclei at z=21
# Identified 0 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:37,915 [INFO] No cell pixels found.
# Identified 0 nuclei at z=22
# Identified 0 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:52:38,401 [INFO] No cell pixels found.
# Identified 0 nuclei at z=23
# Identified 0 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=24
# Identified 0 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=25
# Identified 0 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=26
# Identified 5 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 4 nuclei at z=27
# Identified 4 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 7 nuclei at z=28
# Identified 7 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 15 nuclei at z=29
# Identified 15 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=30
# Identified 33 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 58 nuclei at z=31
# Identified 58 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 93 nuclei at z=32
# Identified 93 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 114 nuclei at z=33
# Identified 114 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 150 nuclei at z=34
# Identified 150 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 169 nuclei at z=35
# Identified 169 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 204 nuclei at z=36
# Identified 204 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 238 nuclei at z=37
# Identified 238 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 245 nuclei at z=38
# Identified 245 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 246 nuclei at z=39
# Identified 246 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 239 nuclei at z=40
# Identified 239 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 268 nuclei at z=41
# Identified 268 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 279 nuclei at z=42
# Identified 279 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 281 nuclei at z=43
# Identified 281 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 281 nuclei at z=44
# Identified 281 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 299 nuclei at z=45
# Identified 299 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 317 nuclei at z=46
# Identified 317 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 324 nuclei at z=47
# Identified 324 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 342 nuclei at z=48
# Identified 342 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 310 nuclei at z=49
# Identified 310 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 328 nuclei at z=50
# Identified 328 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 307 nuclei at z=51
# Identified 307 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 304 nuclei at z=52
# Identified 304 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 321 nuclei at z=53
# Identified 321 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 313 nuclei at z=54
# Identified 313 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 294 nuclei at z=55
# Identified 294 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 307 nuclei at z=56
# Identified 307 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 305 nuclei at z=57
# Identified 305 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 255 nuclei at z=58
# Identified 255 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 260 nuclei at z=59
# Identified 260 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 281 nuclei at z=60
# Identified 281 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 283 nuclei at z=61
# Identified 283 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 306 nuclei at z=62
# Identified 306 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 302 nuclei at z=63
# Identified 302 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 317 nuclei at z=64
# Identified 317 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 311 nuclei at z=65
# Identified 311 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 302 nuclei at z=66
# Identified 302 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 317 nuclei at z=67
# Identified 317 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 349 nuclei at z=68
# Identified 349 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 356 nuclei at z=69
# Identified 356 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 358 nuclei at z=70
# Identified 358 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=71
# Identified 355 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 351 nuclei at z=72
# Identified 351 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 362 nuclei at z=73
# Identified 362 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 363 nuclei at z=74
# Identified 363 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 337 nuclei at z=75
# Identified 337 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 303 nuclei at z=76
# Identified 303 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 287 nuclei at z=77
# Identified 287 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 273 nuclei at z=78
# Identified 273 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 270 nuclei at z=79
# Identified 270 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 265 nuclei at z=80
# Identified 265 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 284 nuclei at z=81
# Identified 284 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 251 nuclei at z=82
# Identified 251 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 266 nuclei at z=83
# Identified 266 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 246 nuclei at z=84
# Identified 246 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 224 nuclei at z=85
# Identified 224 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 222 nuclei at z=86
# Identified 222 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 218 nuclei at z=87
# Identified 218 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 181 nuclei at z=88
# Identified 181 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 172 nuclei at z=89
# Identified 172 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 148 nuclei at z=90
# Identified 148 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 135 nuclei at z=91
# Identified 135 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 111 nuclei at z=92
# Identified 111 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 93 nuclei at z=93
# Identified 93 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 70 nuclei at z=94
# Identified 70 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 58 nuclei at z=95
# Identified 58 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 43 nuclei at z=96
# Identified 43 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 21 nuclei at z=97
# Identified 21 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 12 nuclei at z=98
# Identified 12 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=222
# Identified 2 nuclei at z=99
# Identified 2 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=199
# Identified 4 nuclei at z=100
# Identified 4 nuclei
# ROIs saved to ../results/20250701 C 9E184-B1-546 9E185-186-B2-647/20250701 C sample 6 stack_rois.npy
# Processing 20250701 C sample 7 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (101, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 101
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=108
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=44
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=43
# 2025-07-02 17:54:18,549 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=40
# 2025-07-02 17:54:19,116 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=46
# Error at z=4: tuple index out of range
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=55
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=72
# Error at z=6: tuple index out of range
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=77
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=138
# Identified 1 nuclei at z=8
# Identified 1 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=116
# Identified 1 nuclei at z=9
# Identified 1 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=119
# 2025-07-02 17:54:23,245 [INFO] No cell pixels found.
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=194
# Error at z=11: tuple index out of range
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=201
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=167
# Identified 0 nuclei at z=13
# Identified 0 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=214
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 0 nuclei at z=15
# Identified 0 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:54:26,891 [INFO] No cell pixels found.
# Identified 0 nuclei at z=16
# Identified 0 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:54:27,387 [INFO] No cell pixels found.
# Identified 0 nuclei at z=17
# Identified 0 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=240
# 2025-07-02 17:54:27,893 [INFO] No cell pixels found.
# Identified 0 nuclei at z=18
# Identified 0 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Error at z=19: tuple index out of range
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:54:28,834 [INFO] No cell pixels found.
# Identified 0 nuclei at z=20
# Identified 0 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# 2025-07-02 17:54:29,341 [INFO] No cell pixels found.
# Identified 0 nuclei at z=21
# Identified 0 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# 2025-07-02 17:54:29,819 [INFO] No cell pixels found.
# Identified 0 nuclei at z=22
# Identified 0 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 0 nuclei at z=23
# Identified 0 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=24
# Identified 1 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=25
# Identified 0 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 4 nuclei at z=26
# Identified 4 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 7 nuclei at z=27
# Identified 7 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 32 nuclei at z=28
# Identified 32 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 69 nuclei at z=29
# Identified 69 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 101 nuclei at z=30
# Identified 101 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 121 nuclei at z=31
# Identified 121 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 157 nuclei at z=32
# Identified 157 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 210 nuclei at z=33
# Identified 210 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 256 nuclei at z=34
# Identified 256 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 288 nuclei at z=35
# Identified 288 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 326 nuclei at z=36
# Identified 326 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 372 nuclei at z=37
# Identified 372 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 403 nuclei at z=38
# Identified 403 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 441 nuclei at z=39
# Identified 441 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 436 nuclei at z=40
# Identified 436 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 488 nuclei at z=41
# Identified 488 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=42
# Identified 518 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 547 nuclei at z=43
# Identified 547 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 570 nuclei at z=44
# Identified 570 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 590 nuclei at z=45
# Identified 590 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 579 nuclei at z=46
# Identified 579 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 605 nuclei at z=47
# Identified 605 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 622 nuclei at z=48
# Identified 622 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 638 nuclei at z=49
# Identified 638 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 630 nuclei at z=50
# Identified 630 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 642 nuclei at z=51
# Identified 642 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 630 nuclei at z=52
# Identified 630 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=53
# Identified 633 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 596 nuclei at z=54
# Identified 596 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 594 nuclei at z=55
# Identified 594 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 584 nuclei at z=56
# Identified 584 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=237
# Identified 570 nuclei at z=57
# Identified 570 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=248
# Identified 575 nuclei at z=58
# Identified 575 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=251
# Identified 572 nuclei at z=59
# Identified 572 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=60
# Identified 557 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=242
# Identified 523 nuclei at z=61
# Identified 523 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=230
# Identified 544 nuclei at z=62
# Identified 544 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=230
# Identified 520 nuclei at z=63
# Identified 520 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=219
# Identified 525 nuclei at z=64
# Identified 525 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=238
# Identified 533 nuclei at z=65
# Identified 533 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=66
# Identified 557 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=238
# Identified 553 nuclei at z=67
# Identified 553 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 560 nuclei at z=68
# Identified 560 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=232
# Identified 553 nuclei at z=69
# Identified 553 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=226
# Identified 544 nuclei at z=70
# Identified 544 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=216
# Identified 556 nuclei at z=71
# Identified 556 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=203
# Identified 563 nuclei at z=72
# Identified 563 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=220
# Identified 541 nuclei at z=73
# Identified 541 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=239
# Identified 539 nuclei at z=74
# Identified 539 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 537 nuclei at z=75
# Identified 537 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 514 nuclei at z=76
# Identified 514 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 523 nuclei at z=77
# Identified 523 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 525 nuclei at z=78
# Identified 525 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=226
# Identified 516 nuclei at z=79
# Identified 516 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=80
# Identified 518 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=202
# Identified 499 nuclei at z=81
# Identified 499 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=206
# Identified 472 nuclei at z=82
# Identified 472 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 471 nuclei at z=83
# Identified 471 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=194
# Identified 428 nuclei at z=84
# Identified 428 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 415 nuclei at z=85
# Identified 415 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 406 nuclei at z=86
# Identified 406 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=219
# Identified 398 nuclei at z=87
# Identified 398 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 383 nuclei at z=88
# Identified 383 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=209
# Identified 379 nuclei at z=89
# Identified 379 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=213
# Identified 363 nuclei at z=90
# Identified 363 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=166
# Identified 350 nuclei at z=91
# Identified 350 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=179
# Identified 311 nuclei at z=92
# Identified 311 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=171
# Identified 276 nuclei at z=93
# Identified 276 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=170
# Identified 253 nuclei at z=94
# Identified 253 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 222 nuclei at z=95
# Identified 222 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 194 nuclei at z=96
# Identified 194 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 135 nuclei at z=97
# Identified 135 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=145
# Identified 97 nuclei at z=98
# Identified 97 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 46 nuclei at z=99
# Identified 46 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=161
# Identified 19 nuclei at z=100
# Identified 19 nuclei
# ROIs saved to ../results/20250701 C 9E184-B1-546 9E185-186-B2-647/20250701 C sample 7 stack_rois.npy
# Processing 20250701 C sample 4 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (101, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 101
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=36
# 2025-07-02 17:56:42,818 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=70
# 2025-07-02 17:56:43,332 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=65
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=48
# 2025-07-02 17:56:44,476 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=51
# Error at z=4: tuple index out of range
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=55
# Error at z=5: tuple index out of range
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=80
# Error at z=6: tuple index out of range
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=69
# Error at z=7: tuple index out of range
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=54
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=116
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# 2025-07-02 17:56:49,472 [INFO] No cell pixels found.
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=215
# Error at z=11: tuple index out of range
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=13
# Identified 1 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:52,767 [INFO] No cell pixels found.
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:53,456 [INFO] No cell pixels found.
# Identified 0 nuclei at z=15
# Identified 0 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:54,155 [INFO] No cell pixels found.
# Identified 0 nuclei at z=16
# Identified 0 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=17
# Identified 0 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:55,680 [INFO] No cell pixels found.
# Identified 0 nuclei at z=18
# Identified 0 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:56,382 [INFO] No cell pixels found.
# Identified 0 nuclei at z=19
# Identified 0 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:57,124 [INFO] No cell pixels found.
# Identified 0 nuclei at z=20
# Identified 0 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:56:57,808 [INFO] No cell pixels found.
# Identified 0 nuclei at z=21
# Identified 0 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 2 nuclei at z=22
# Identified 2 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=23
# Identified 6 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 14 nuclei at z=24
# Identified 14 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 18 nuclei at z=25
# Identified 18 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 29 nuclei at z=26
# Identified 29 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 52 nuclei at z=27
# Identified 52 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 80 nuclei at z=28
# Identified 80 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 123 nuclei at z=29
# Identified 123 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 165 nuclei at z=30
# Identified 165 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 203 nuclei at z=31
# Identified 203 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 238 nuclei at z=32
# Identified 238 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 294 nuclei at z=33
# Identified 294 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 333 nuclei at z=34
# Identified 333 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 367 nuclei at z=35
# Identified 367 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 418 nuclei at z=36
# Identified 418 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 429 nuclei at z=37
# Identified 429 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 472 nuclei at z=38
# Identified 472 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 475 nuclei at z=39
# Identified 475 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 487 nuclei at z=40
# Identified 487 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 474 nuclei at z=41
# Identified 474 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 482 nuclei at z=42
# Identified 482 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 498 nuclei at z=43
# Identified 498 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 525 nuclei at z=44
# Identified 525 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 498 nuclei at z=45
# Identified 498 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 501 nuclei at z=46
# Identified 501 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 524 nuclei at z=47
# Identified 524 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 524 nuclei at z=48
# Identified 524 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=49
# Identified 535 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 540 nuclei at z=50
# Identified 540 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=51
# Identified 536 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 544 nuclei at z=52
# Identified 544 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 548 nuclei at z=53
# Identified 548 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 539 nuclei at z=54
# Identified 539 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 545 nuclei at z=55
# Identified 545 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 542 nuclei at z=56
# Identified 542 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=57
# Identified 536 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=58
# Identified 536 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 519 nuclei at z=59
# Identified 519 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 513 nuclei at z=60
# Identified 513 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 485 nuclei at z=61
# Identified 485 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 482 nuclei at z=62
# Identified 482 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 475 nuclei at z=63
# Identified 475 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 510 nuclei at z=64
# Identified 510 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 544 nuclei at z=65
# Identified 544 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 567 nuclei at z=66
# Identified 567 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 565 nuclei at z=67
# Identified 565 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 600 nuclei at z=68
# Identified 600 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 642 nuclei at z=69
# Identified 642 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 645 nuclei at z=70
# Identified 645 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 652 nuclei at z=71
# Identified 652 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 656 nuclei at z=72
# Identified 656 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 642 nuclei at z=73
# Identified 642 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 655 nuclei at z=74
# Identified 655 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 659 nuclei at z=75
# Identified 659 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 660 nuclei at z=76
# Identified 660 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 618 nuclei at z=77
# Identified 618 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 612 nuclei at z=78
# Identified 612 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 599 nuclei at z=79
# Identified 599 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 579 nuclei at z=80
# Identified 579 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 576 nuclei at z=81
# Identified 576 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=82
# Identified 535 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=83
# Identified 504 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 456 nuclei at z=84
# Identified 456 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 446 nuclei at z=85
# Identified 446 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 414 nuclei at z=86
# Identified 414 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 404 nuclei at z=87
# Identified 404 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 387 nuclei at z=88
# Identified 387 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 350 nuclei at z=89
# Identified 350 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=249
# Identified 339 nuclei at z=90
# Identified 339 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 304 nuclei at z=91
# Identified 304 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=238
# Identified 269 nuclei at z=92
# Identified 269 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=235
# Identified 226 nuclei at z=93
# Identified 226 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 216 nuclei at z=94
# Identified 216 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 188 nuclei at z=95
# Identified 188 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=216
# Identified 159 nuclei at z=96
# Identified 159 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=215
# Identified 113 nuclei at z=97
# Identified 113 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=200
# Identified 68 nuclei at z=98
# Identified 68 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 42 nuclei at z=99
# Identified 42 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 31 nuclei at z=100
# Identified 31 nuclei
# ROIs saved to ../results/20250701 C 9E184-B1-546 9E185-186-B2-647/20250701 C sample 4 stack_rois.npy
# Processing 20250701 C sample 5 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (101, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 101
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=163
# 2025-07-02 17:59:12,413 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=151
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=135
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=156
# 2025-07-02 17:59:15,359 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=209
# Error at z=4: tuple index out of range
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=7
# Identified 1 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:19,282 [INFO] No cell pixels found.
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:19,955 [INFO] No cell pixels found.
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:20,639 [INFO] No cell pixels found.
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:21,318 [INFO] No cell pixels found.
# Identified 0 nuclei at z=11
# Identified 0 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:22,005 [INFO] No cell pixels found.
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:22,673 [INFO] No cell pixels found.
# Identified 0 nuclei at z=13
# Identified 0 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:23,338 [INFO] No cell pixels found.
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:24,010 [INFO] No cell pixels found.
# Identified 0 nuclei at z=15
# Identified 0 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 17:59:24,662 [INFO] No cell pixels found.
# Identified 0 nuclei at z=16
# Identified 0 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=17
# Identified 3 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=18
# Identified 5 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 7 nuclei at z=19
# Identified 7 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 12 nuclei at z=20
# Identified 12 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 14 nuclei at z=21
# Identified 14 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 34 nuclei at z=22
# Identified 34 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 47 nuclei at z=23
# Identified 47 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 116 nuclei at z=24
# Identified 116 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 190 nuclei at z=25
# Identified 190 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 254 nuclei at z=26
# Identified 254 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 304 nuclei at z=27
# Identified 304 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 340 nuclei at z=28
# Identified 340 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=29
# Identified 384 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 406 nuclei at z=30
# Identified 406 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 477 nuclei at z=31
# Identified 477 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=32
# Identified 504 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 552 nuclei at z=33
# Identified 552 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=34
# Identified 557 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 580 nuclei at z=35
# Identified 580 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 568 nuclei at z=36
# Identified 568 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 549 nuclei at z=37
# Identified 549 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 570 nuclei at z=38
# Identified 570 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 558 nuclei at z=39
# Identified 558 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 565 nuclei at z=40
# Identified 565 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 560 nuclei at z=41
# Identified 560 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 558 nuclei at z=42
# Identified 558 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 524 nuclei at z=43
# Identified 524 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 540 nuclei at z=44
# Identified 540 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 558 nuclei at z=45
# Identified 558 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 554 nuclei at z=46
# Identified 554 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 537 nuclei at z=47
# Identified 537 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 484 nuclei at z=48
# Identified 484 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 495 nuclei at z=49
# Identified 495 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=50
# Identified 535 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 546 nuclei at z=51
# Identified 546 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 541 nuclei at z=52
# Identified 541 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 512 nuclei at z=53
# Identified 512 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 506 nuclei at z=54
# Identified 506 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 497 nuclei at z=55
# Identified 497 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 474 nuclei at z=56
# Identified 474 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 426 nuclei at z=57
# Identified 426 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=58
# Identified 425 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 418 nuclei at z=59
# Identified 418 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 458 nuclei at z=60
# Identified 458 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=61
# Identified 518 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 527 nuclei at z=62
# Identified 527 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 532 nuclei at z=63
# Identified 532 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 561 nuclei at z=64
# Identified 561 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 577 nuclei at z=65
# Identified 577 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 598 nuclei at z=66
# Identified 598 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 651 nuclei at z=67
# Identified 651 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 640 nuclei at z=68
# Identified 640 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 604 nuclei at z=69
# Identified 604 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 608 nuclei at z=70
# Identified 608 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 617 nuclei at z=71
# Identified 617 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=72
# Identified 633 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 632 nuclei at z=73
# Identified 632 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 597 nuclei at z=74
# Identified 597 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 572 nuclei at z=75
# Identified 572 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 573 nuclei at z=76
# Identified 573 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=77
# Identified 557 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 538 nuclei at z=78
# Identified 538 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 528 nuclei at z=79
# Identified 528 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 514 nuclei at z=80
# Identified 514 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 480 nuclei at z=81
# Identified 480 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 442 nuclei at z=82
# Identified 442 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=83
# Identified 415 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 396 nuclei at z=84
# Identified 396 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=85
# Identified 355 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 329 nuclei at z=86
# Identified 329 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 294 nuclei at z=87
# Identified 294 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=252
# Identified 249 nuclei at z=88
# Identified 249 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 198 nuclei at z=89
# Identified 198 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 165 nuclei at z=90
# Identified 165 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=215
# Identified 118 nuclei at z=91
# Identified 118 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 77 nuclei at z=92
# ...
# Identified 343 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 374 nuclei at z=68
# Identified 374 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=69
# Identified 355 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=162
# Identified 359 nuclei at z=70
# Identified 359 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=164
# Identified 325 nuclei at z=71
# Identified 325 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=158
# Identified 290 nuclei at z=72
# Identified 290 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=199
# Identified 307 nuclei at z=73
# Identified 307 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=160
# Identified 279 nuclei at z=74
# Identified 279 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 296 nuclei at z=75
# Identified 296 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=202
# Identified 284 nuclei at z=76
# Identified 284 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 258 nuclei at z=77
# Identified 258 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 237 nuclei at z=78
# Identified 237 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=142
# Identified 219 nuclei at z=79
# Identified 219 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=167
# Identified 192 nuclei at z=80
# Identified 192 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=137
# Identified 163 nuclei at z=81
# Identified 163 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=169
# Identified 125 nuclei at z=82
# Identified 125 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=203
# Identified 109 nuclei at z=83
# Identified 109 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=208
# Identified 85 nuclei at z=84
# Identified 85 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=130
# Identified 62 nuclei at z=85
# Identified 62 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=129
# Identified 31 nuclei at z=86
# Identified 31 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=129
# Identified 18 nuclei at z=87
# Identified 18 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=142
# Identified 10 nuclei at z=88
# Identified 10 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=131
# Identified 5 nuclei at z=89
# Identified 5 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 3 nuclei at z=90
# Identified 3 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=225
# Identified 2 nuclei at z=91
# Identified 2 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=93
# 2025-07-02 18:05:43,991 [INFO] No cell pixels found.
# Identified 0 nuclei at z=92
# Identified 0 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=127
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=151
# Identified 0 nuclei at z=94
# Identified 0 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=90
# 2025-07-02 18:05:45,786 [INFO] No cell pixels found.
# Identified 0 nuclei at z=95
# Identified 0 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=132
# Identified 0 nuclei at z=96
# Identified 0 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=120
# Identified 0 nuclei at z=97
# Identified 0 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=93
# Identified 1 nuclei at z=98
# Identified 1 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=83
# Identified 0 nuclei at z=99
# Identified 0 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=100
# Identified 1 nuclei at z=100
# Identified 1 nuclei
# ROIs saved to ../results/20250701 C 9E184-B1-546 9E185-186-B2-647/20250701 C sample 3 stack_rois.npy
# Processing 20250701 C sample 1 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'DAPI-T2', 'AF647-T2']}
# Image shape: (101, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 101
# Z resolution: 1.0 um
# DAPI channel index: 1
# Non-DAPI channels: [(0, 'AF546-T1'), (2, 'AF647-T2')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 18:06:35,127 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 18:06:35,608 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 18:06:36,083 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-07-02 18:06:36,587 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 13 nuclei at z=4
# Identified 13 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 21 nuclei at z=5
# Identified 21 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 18 nuclei at z=6
# Identified 18 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=7
# Identified 33 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 30 nuclei at z=8
# Identified 30 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 46 nuclei at z=9
# Identified 46 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 62 nuclei at z=10
# Identified 62 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 56 nuclei at z=11
# Identified 56 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 82 nuclei at z=12
# Identified 82 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 108 nuclei at z=13
# Identified 108 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 145 nuclei at z=14
# Identified 145 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=252
# Identified 182 nuclei at z=15
# Identified 182 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 200 nuclei at z=16
# Identified 200 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 263 nuclei at z=17
# Identified 263 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 303 nuclei at z=18
# Identified 303 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 312 nuclei at z=19
# Identified 312 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 350 nuclei at z=20
# Identified 350 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 381 nuclei at z=21
# Identified 381 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 405 nuclei at z=22
# Identified 405 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=232
# Identified 398 nuclei at z=23
# Identified 398 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 398 nuclei at z=24
# Identified 398 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 394 nuclei at z=25
# Identified 394 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 358 nuclei at z=26
# Identified 358 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=27
# Identified 355 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 359 nuclei at z=28
# Identified 359 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 389 nuclei at z=29
# Identified 389 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 397 nuclei at z=30
# Identified 397 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 414 nuclei at z=31
# Identified 414 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 446 nuclei at z=32
# Identified 446 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 469 nuclei at z=33
# Identified 469 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 468 nuclei at z=34
# Identified 468 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 492 nuclei at z=35
# Identified 492 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=234
# Identified 506 nuclei at z=36
# Identified 506 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 509 nuclei at z=37
# Identified 509 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 507 nuclei at z=38
# Identified 507 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# Identified 509 nuclei at z=39
# Identified 509 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=233
# Identified 536 nuclei at z=40
# Identified 536 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=217
# Identified 556 nuclei at z=41
# Identified 556 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=211
# Identified 553 nuclei at z=42
# Identified 553 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=217
# Identified 545 nuclei at z=43
# Identified 545 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=177
# Identified 520 nuclei at z=44
# Identified 520 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=193
# Identified 504 nuclei at z=45
# Identified 504 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=229
# Identified 502 nuclei at z=46
# Identified 502 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 503 nuclei at z=47
# Identified 503 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=196
# Identified 524 nuclei at z=48
# Identified 524 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 563 nuclei at z=49
# Identified 563 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=176
# Identified 567 nuclei at z=50
# Identified 567 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 573 nuclei at z=51
# Identified 573 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=198
# Identified 603 nuclei at z=52
# Identified 603 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# Identified 588 nuclei at z=53
# Identified 588 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=198
# Identified 560 nuclei at z=54
# Identified 560 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=168
# Identified 592 nuclei at z=55
# Identified 592 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=169
# Identified 601 nuclei at z=56
# Identified 601 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 578 nuclei at z=57
# Identified 578 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=223
# Identified 582 nuclei at z=58
# Identified 582 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 572 nuclei at z=59
# Identified 572 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=216
# Identified 532 nuclei at z=60
# Identified 532 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=156
# Identified 533 nuclei at z=61
# Identified 533 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=187
# Identified 532 nuclei at z=62
# Identified 532 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=183
# Identified 460 nuclei at z=63
# Identified 460 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=199
# Identified 434 nuclei at z=64
# Identified 434 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 420 nuclei at z=65
# Identified 420 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 357 nuclei at z=66
# Identified 357 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 344 nuclei at z=67
# Identified 344 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=168
# Identified 345 nuclei at z=68
# Identified 345 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=171
# Identified 298 nuclei at z=69
# Identified 298 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=139
# Identified 290 nuclei at z=70
# Identified 290 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=141
# Identified 263 nuclei at z=71
# Identified 263 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=166
# Identified 239 nuclei at z=72
# Identified 239 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=139
# Identified 220 nuclei at z=73
# Identified 220 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=136
# Identified 194 nuclei at z=74
# Identified 194 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=130
# Identified 163 nuclei at z=75
# Identified 163 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=176
# Identified 156 nuclei at z=76
# Identified 156 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=129
# Identified 108 nuclei at z=77
# Identified 108 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=193
# Identified 71 nuclei at z=78
# Identified 71 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=110
# Identified 56 nuclei at z=79
# Identified 56 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=137
# Identified 35 nuclei at z=80
# Identified 35 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=151
# Identified 19 nuclei at z=81
# Identified 19 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=131
# Identified 12 nuclei at z=82
# Identified 12 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=166
# Identified 5 nuclei at z=83
# Identified 5 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=161
# Identified 2 nuclei at z=84
# Identified 2 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=117
# Identified 9 nuclei at z=85
# Identified 9 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=147
# Identified 4 nuclei at z=86
# Identified 4 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# Identified 3 nuclei at z=87
# Identified 3 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=123
# Identified 2 nuclei at z=88
# Identified 2 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=114
# Identified 0 nuclei at z=89
# Identified 0 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=126
# 2025-07-02 18:07:44,730 [INFO] No cell pixels found.
# Identified 0 nuclei at z=90
# Identified 0 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=211
# 2025-07-02 18:07:45,908 [INFO] No cell pixels found.
# Identified 0 nuclei at z=92
# Identified 0 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=140
# 2025-07-02 18:07:46,414 [INFO] No cell pixels found.
# Identified 0 nuclei at z=93
# Identified 0 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=135
# 2025-07-02 18:07:46,912 [INFO] No cell pixels found.
# Identified 0 nuclei at z=94
# Identified 0 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=149
# 2025-07-02 18:07:47,407 [INFO] No cell pixels found.
# Identified 0 nuclei at z=95
# Identified 0 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=118
# 2025-07-02 18:07:47,915 [INFO] No cell pixels found.
# Identified 0 nuclei at z=96
# Identified 0 nuclei
# Z=97 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=120
# 2025-07-02 18:07:48,410 [INFO] No cell pixels found.
# Identified 0 nuclei at z=97
# Identified 0 nuclei
# Z=98 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=107
# Identified 0 nuclei at z=98
# Identified 0 nuclei
# Z=99 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=78
# Identified 1 nuclei at z=99
# Identified 1 nuclei
# Z=100 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=68
# Identified 5 nuclei at z=100
# Identified 5 nuclei
# ROIs saved to ../results/20250701 C 9E184-B1-546 9E185-186-B2-647/20250701 C sample 1 stack_rois.npy

# %% [markdown]
# ## Run on all files

# %%
raw_data_dirs = os.listdir('../../../RNA-FISH-raw-data/')
raw_data_p14 = [d for d in raw_data_dirs if '20250813' in d]
raw_data_p14
# Out:
# ['20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI',
#  '20250813 B P14 U34-B3-488 Lnc4-B1-546 U21-B5-647 DAPI',
#  '20250813 D P14 9E118-exons-B1-546 9E118-introns-B2-647 9E129-B3-488 DAPI',
#  '20250813 A P14 P1-B1-546 P2-B2-647 P1-antisense-B3-488 DAPI']

# %%
# Load trained model 
model_path = '../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs'
model = models.CellposeModel(gpu=True, pretrained_model=model_path)
# Out:
# 2025-08-15 12:58:26,421 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-15 12:58:26,422 [INFO] >>>> using GPU (CUDA)
# 2025-08-15 12:58:26,459 [INFO] >>>> loading model ../cellpose-model-training/model_B_only_OSNs/models/model_B_only_OSNs
# 2025-08-15 12:58:26,490 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# 2025-08-15 12:58:26,491 [INFO] >>>> model diam_labels =  29.464 (mean diameter of training ROIs)

# %%
for input in raw_data_p14: 

    input_dir = f'../../../RNA-FISH-raw-data/{input}/'
    assert os.path.exists(input_dir), 'Input directory does not exist'
    czi_files = [f for f in os.listdir(input_dir) if f.endswith('.czi')]
    print(f"Found {len(czi_files)} czi files in {input_dir}")
    print(czi_files)

    results_dir = f'../results/{input}'
    if not os.path.exists(results_dir):
        os.makedirs(results_dir)
        
    for f in czi_files[:]:
        print(f"Processing {f}")
        file_path = os.path.join(input_dir, f)
        reader = napari_get_reader(file_path)
        if reader is not None:
            layer_data = reader(file_path)
            image_data, metadata, layer_type = layer_data[0]
            # Remove singleton dimension 
            image_data = np.squeeze(image_data)  
            print("Metadata:", metadata)
            print("Image shape:", image_data.shape)  
            print(f"Number of NaN pixels: {np.sum(np.isnan(image_data))}")

            pixel_x = metadata['scale'][2]
            print(f"Pixel size: {pixel_x} um")

            xy_resolution = image_data.shape[-1] 
            print(f"XY resolution: {xy_resolution} pixels")

            nucleus_diameter = 3 / pixel_x
            print(f"Nucleus diameter: {nucleus_diameter} pixels") 
            
            z_slices = image_data.shape[0]
            print(f"Z slices: {z_slices}")

            z_um = metadata['scale'][1]
            print(f"Z resolution: {z_um} um")

            dapi_index = metadata['name'].index([name for name in metadata['name'] if 'DAPI' in name][0])
            print(f"DAPI channel index: {dapi_index}")

            non_dapi_channels = [(i, metadata['name'][i]) for i in range(len(metadata['name'])) if i != dapi_index]
            print(f"Non-DAPI channels: {non_dapi_channels}")

            all_rois = np.zeros_like(image_data[:, dapi_index, :, :], dtype=np.uint16)
            for z in range(z_slices):
                image_data_z = image_data[z, dapi_index, :, :]
                print(f"Z={z} | shape={image_data_z.shape} | dtype={image_data_z.dtype} | min={image_data_z.min()} | max={image_data_z.max()}")
                try:
                    rois, flows, styles = model.eval(image_data_z, diameter=nucleus_diameter)
                    print(f"Identified {rois.max()} nuclei at z={z}")
                except Exception as e:
                    print(f"Error at z={z}: {e}")
                    continue
                print(f"Identified {rois.max()} nuclei")
                all_rois[z, :, :] = rois

            # Save the masks to a file 
            all_rois_path = os.path.join(results_dir, f.replace('.czi', f'_rois.npy'))
            np.save(all_rois_path, all_rois)
            print(f"ROIs saved to {all_rois_path}")
# Out:
# Found 8 czi files in ../../../RNA-FISH-raw-data/20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI/
# ['20250813 C sample 8 stack.czi', '20250813 C sample 5 stack.czi', '20250813 C sample 4 stack.czi', '20250813 C sample 7 stack.czi', '20250813 C sample 6 stack.czi', '20250813 C sample 1 stack.czi', '20250813 C sample 3 stack.czi', '20250813 C sample 2 stack.czi']
# Processing 20250813 C sample 8 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2']}
# Image shape: (92, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 92
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 12:58:57,862 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 2 nuclei at z=1
# Identified 2 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 12 nuclei at z=2
# Identified 12 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 10 nuclei at z=3
# Identified 10 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 13 nuclei at z=4
# Identified 13 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 21 nuclei at z=5
# Identified 21 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 34 nuclei at z=6
# Identified 34 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 48 nuclei at z=7
# Identified 48 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 86 nuclei at z=8
# Identified 86 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 122 nuclei at z=9
# Identified 122 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 177 nuclei at z=10
# Identified 177 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 215 nuclei at z=11
# Identified 215 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 260 nuclei at z=12
# Identified 260 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 315 nuclei at z=13
# Identified 315 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 349 nuclei at z=14
# Identified 349 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 371 nuclei at z=15
# Identified 371 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 409 nuclei at z=16
# Identified 409 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 463 nuclei at z=17
# Identified 463 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 494 nuclei at z=18
# Identified 494 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 502 nuclei at z=19
# Identified 502 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 504 nuclei at z=20
# Identified 504 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 511 nuclei at z=21
# Identified 511 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 509 nuclei at z=22
# Identified 509 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 514 nuclei at z=23
# Identified 514 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 539 nuclei at z=24
# Identified 539 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=25
# Identified 551 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=26
# Identified 536 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 520 nuclei at z=27
# Identified 520 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 541 nuclei at z=28
# Identified 541 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=29
# Identified 535 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 566 nuclei at z=30
# Identified 566 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 545 nuclei at z=31
# Identified 545 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 564 nuclei at z=32
# Identified 564 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 566 nuclei at z=33
# Identified 566 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 568 nuclei at z=34
# Identified 568 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 560 nuclei at z=35
# Identified 560 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 560 nuclei at z=36
# Identified 560 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 567 nuclei at z=37
# Identified 567 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 568 nuclei at z=38
# Identified 568 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=39
# Identified 551 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=40
# Identified 550 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=41
# Identified 550 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 535 nuclei at z=42
# Identified 535 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 508 nuclei at z=43
# Identified 508 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 498 nuclei at z=44
# Identified 498 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 493 nuclei at z=45
# Identified 493 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 511 nuclei at z=46
# Identified 511 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=47
# Identified 518 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 543 nuclei at z=48
# Identified 543 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 556 nuclei at z=49
# Identified 556 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 548 nuclei at z=50
# Identified 548 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=51
# Identified 551 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=52
# Identified 557 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 557 nuclei at z=53
# Identified 557 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 528 nuclei at z=54
# Identified 528 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 541 nuclei at z=55
# Identified 541 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 510 nuclei at z=56
# Identified 510 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 492 nuclei at z=57
# Identified 492 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 496 nuclei at z=58
# Identified 496 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 507 nuclei at z=59
# Identified 507 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=60
# Identified 518 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 502 nuclei at z=61
# Identified 502 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 464 nuclei at z=62
# Identified 464 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 467 nuclei at z=63
# Identified 467 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 451 nuclei at z=64
# Identified 451 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 473 nuclei at z=65
# Identified 473 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 457 nuclei at z=66
# Identified 457 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 440 nuclei at z=67
# Identified 440 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 396 nuclei at z=68
# Identified 396 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 376 nuclei at z=69
# Identified 376 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 334 nuclei at z=70
# Identified 334 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 306 nuclei at z=71
# Identified 306 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 279 nuclei at z=72
# Identified 279 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 235 nuclei at z=73
# Identified 235 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 202 nuclei at z=74
# Identified 202 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 153 nuclei at z=75
# Identified 153 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 110 nuclei at z=76
# Identified 110 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 98 nuclei at z=77
# Identified 98 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 74 nuclei at z=78
# Identified 74 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 57 nuclei at z=79
# Identified 57 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=80
# Identified 33 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 39 nuclei at z=81
# Identified 39 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 34 nuclei at z=82
# Identified 34 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 33 nuclei at z=83
# Identified 33 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 18 nuclei at z=84
# Identified 18 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 11 nuclei at z=85
# Identified 11 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=86
# Identified 3 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=221
# 2025-08-15 13:00:13,080 [INFO] No cell pixels found.
# Identified 0 nuclei at z=87
# Identified 0 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=254
# Identified 0 nuclei at z=88
# Identified 0 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=246
# 2025-08-15 13:00:14,200 [INFO] No cell pixels found.
# Identified 0 nuclei at z=89
# Identified 0 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:14,686 [INFO] No cell pixels found.
# Identified 0 nuclei at z=90
# Identified 0 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:15,174 [INFO] No cell pixels found.
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# ROIs saved to ../results/20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI/20250813 C sample 8 stack_rois.npy
# Processing 20250813 C sample 5 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2']}
# Image shape: (92, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 92
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:45,658 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:46,262 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:46,831 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:00:47,326 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 4 nuclei at z=5
# Identified 4 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 14 nuclei at z=6
# Identified 14 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 27 nuclei at z=7
# Identified 27 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 13 nuclei at z=8
# Identified 13 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 29 nuclei at z=9
# Identified 29 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 52 nuclei at z=10
# Identified 52 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 89 nuclei at z=11
# Identified 89 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 120 nuclei at z=12
# Identified 120 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 169 nuclei at z=13
# Identified 169 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 239 nuclei at z=14
# Identified 239 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 290 nuclei at z=15
# Identified 290 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 316 nuclei at z=16
# Identified 316 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 366 nuclei at z=17
# Identified 366 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 403 nuclei at z=18
# Identified 403 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 424 nuclei at z=19
# Identified 424 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 445 nuclei at z=20
# Identified 445 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 476 nuclei at z=21
# Identified 476 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 462 nuclei at z=22
# Identified 462 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 450 nuclei at z=23
# Identified 450 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 456 nuclei at z=24
# Identified 456 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 471 nuclei at z=25
# Identified 471 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 459 nuclei at z=26
# Identified 459 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 450 nuclei at z=27
# Identified 450 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 437 nuclei at z=28
# Identified 437 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 442 nuclei at z=29
# Identified 442 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 444 nuclei at z=30
# Identified 444 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=31
# Identified 439 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 461 nuclei at z=32
# Identified 461 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 436 nuclei at z=33
# Identified 436 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 435 nuclei at z=34
# Identified 435 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 420 nuclei at z=35
# Identified 420 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 443 nuclei at z=36
# Identified 443 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 442 nuclei at z=37
# Identified 442 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 438 nuclei at z=38
# Identified 438 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 392 nuclei at z=39
# Identified 392 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 406 nuclei at z=40
# Identified 406 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 384 nuclei at z=41
# Identified 384 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 408 nuclei at z=42
# Identified 408 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 419 nuclei at z=43
# Identified 419 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=44
# Identified 439 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=45
# Identified 439 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 475 nuclei at z=46
# Identified 475 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 501 nuclei at z=47
# Identified 501 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 521 nuclei at z=48
# Identified 521 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 533 nuclei at z=49
# Identified 533 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 555 nuclei at z=50
# Identified 555 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 562 nuclei at z=51
# Identified 562 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 560 nuclei at z=52
# Identified 560 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 575 nuclei at z=53
# Identified 575 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 570 nuclei at z=54
# Identified 570 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 558 nuclei at z=55
# Identified 558 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=56
# Identified 550 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 546 nuclei at z=57
# Identified 546 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 543 nuclei at z=58
# Identified 543 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 518 nuclei at z=59
# Identified 518 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 519 nuclei at z=60
# Identified 519 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 498 nuclei at z=61
# Identified 498 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 506 nuclei at z=62
# Identified 506 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 496 nuclei at z=63
# Identified 496 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 506 nuclei at z=64
# Identified 506 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 476 nuclei at z=65
# Identified 476 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 459 nuclei at z=66
# Identified 459 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 442 nuclei at z=67
# Identified 442 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 433 nuclei at z=68
# Identified 433 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 451 nuclei at z=69
# Identified 451 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 449 nuclei at z=70
# Identified 449 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 415 nuclei at z=71
# Identified 415 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 406 nuclei at z=72
# Identified 406 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 376 nuclei at z=73
# Identified 376 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 358 nuclei at z=74
# Identified 358 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 312 nuclei at z=75
# Identified 312 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 291 nuclei at z=76
# Identified 291 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 278 nuclei at z=77
# Identified 278 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 258 nuclei at z=78
# Identified 258 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 231 nuclei at z=79
# Identified 231 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 209 nuclei at z=80
# Identified 209 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 181 nuclei at z=81
# Identified 181 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 130 nuclei at z=82
# Identified 130 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 96 nuclei at z=83
# Identified 96 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 64 nuclei at z=84
# Identified 64 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 51 nuclei at z=85
# Identified 51 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 37 nuclei at z=86
# Identified 37 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 45 nuclei at z=87
# Identified 45 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 40 nuclei at z=88
# Identified 40 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 19 nuclei at z=89
# Identified 19 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=90
# Identified 5 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# ROIs saved to ../results/20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI/20250813 C sample 5 stack_rois.npy
# Processing 20250813 C sample 4 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2']}
# Image shape: (92, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 92
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=0
# Identified 1 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:25,695 [INFO] No cell pixels found.
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:26,185 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:26,655 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:27,113 [INFO] No cell pixels found.
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:27,576 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:28,044 [INFO] No cell pixels found.
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:28,508 [INFO] No cell pixels found.
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:02:28,965 [INFO] No cell pixels found.
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=9
# Identified 1 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 9 nuclei at z=10
# Identified 9 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 23 nuclei at z=11
# Identified 23 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 40 nuclei at z=12
# Identified 40 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 45 nuclei at z=13
# Identified 45 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 24 nuclei at z=14
# Identified 24 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 29 nuclei at z=15
# Identified 29 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 41 nuclei at z=16
# Identified 41 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 66 nuclei at z=17
# Identified 66 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 111 nuclei at z=18
# Identified 111 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 139 nuclei at z=19
# Identified 139 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 170 nuclei at z=20
# Identified 170 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 182 nuclei at z=21
# Identified 182 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 210 nuclei at z=22
# Identified 210 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 255 nuclei at z=23
# Identified 255 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 276 nuclei at z=24
# Identified 276 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 307 nuclei at z=25
# Identified 307 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 333 nuclei at z=26
# Identified 333 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 373 nuclei at z=27
# Identified 373 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 411 nuclei at z=28
# Identified 411 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 424 nuclei at z=29
# Identified 424 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 457 nuclei at z=30
# Identified 457 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 458 nuclei at z=31
# Identified 458 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 509 nuclei at z=32
# Identified 509 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 531 nuclei at z=33
# Identified 531 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 554 nuclei at z=34
# Identified 554 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 561 nuclei at z=35
# Identified 561 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 556 nuclei at z=36
# Identified 556 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 562 nuclei at z=37
# Identified 562 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 542 nuclei at z=38
# Identified 542 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 512 nuclei at z=39
# Identified 512 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 490 nuclei at z=40
# Identified 490 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 468 nuclei at z=41
# Identified 468 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 481 nuclei at z=42
# Identified 481 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 497 nuclei at z=43
# Identified 497 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 479 nuclei at z=44
# Identified 479 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 480 nuclei at z=45
# Identified 480 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 467 nuclei at z=46
# Identified 467 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 482 nuclei at z=47
# Identified 482 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 481 nuclei at z=48
# Identified 481 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 494 nuclei at z=49
# Identified 494 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 490 nuclei at z=50
# Identified 490 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 488 nuclei at z=51
# Identified 488 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 472 nuclei at z=52
# Identified 472 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 440 nuclei at z=53
# Identified 440 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 435 nuclei at z=54
# Identified 435 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 416 nuclei at z=55
# Identified 416 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 400 nuclei at z=56
# Identified 400 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 417 nuclei at z=57
# Identified 417 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 413 nuclei at z=58
# Identified 413 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 390 nuclei at z=59
# Identified 390 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 349 nuclei at z=60
# Identified 349 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 282 nuclei at z=61
# Identified 282 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 279 nuclei at z=62
# Identified 279 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 276 nuclei at z=63
# Identified 276 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 272 nuclei at z=64
# Identified 272 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 278 nuclei at z=65
# Identified 278 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 301 nuclei at z=66
# Identified 301 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 283 nuclei at z=67
# Identified 283 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 263 nuclei at z=68
# Identified 263 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 237 nuclei at z=69
# Identified 237 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 230 nuclei at z=70
# Identified 230 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 202 nuclei at z=71
# Identified 202 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 173 nuclei at z=72
# Identified 173 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 145 nuclei at z=73
# Identified 145 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 117 nuclei at z=74
# Identified 117 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 95 nuclei at z=75
# Identified 95 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 71 nuclei at z=76
# Identified 71 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 51 nuclei at z=77
# Identified 51 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 34 nuclei at z=78
# Identified 34 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 23 nuclei at z=79
# Identified 23 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 11 nuclei at z=80
# Identified 11 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 19 nuclei at z=81
# Identified 19 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=244
# Identified 28 nuclei at z=82
# Identified 28 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 35 nuclei at z=83
# Identified 35 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 36 nuclei at z=84
# Identified 36 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 18 nuclei at z=85
# Identified 18 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=244
# Identified 22 nuclei at z=86
# Identified 22 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 11 nuclei at z=87
# Identified 11 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=210
# Identified 8 nuclei at z=88
# Identified 8 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=182
# Identified 5 nuclei at z=89
# Identified 5 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=226
# Identified 1 nuclei at z=90
# Identified 1 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=197
# 2025-08-15 13:03:32,458 [INFO] No cell pixels found.
# Identified 0 nuclei at z=91
# Identified 0 nuclei
# ROIs saved to ../results/20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI/20250813 C sample 4 stack_rois.npy
# Processing 20250813 C sample 7 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2']}
# Image shape: (92, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 92
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 28 nuclei at z=0
# Identified 28 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 30 nuclei at z=1
# Identified 30 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 30 nuclei at z=2
# Identified 30 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 19 nuclei at z=3
# Identified 19 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 13 nuclei at z=4
# Identified 13 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 22 nuclei at z=5
# Identified 22 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 23 nuclei at z=6
# Identified 23 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 36 nuclei at z=7
# Identified 36 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 76 nuclei at z=8
# Identified 76 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 124 nuclei at z=9
# Identified 124 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 198 nuclei at z=10
# Identified 198 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 253 nuclei at z=11
# Identified 253 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 297 nuclei at z=12
# Identified 297 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 322 nuclei at z=13
# Identified 322 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 358 nuclei at z=14
# Identified 358 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 423 nuclei at z=15
# Identified 423 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 439 nuclei at z=16
# Identified 439 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 467 nuclei at z=17
# Identified 467 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 491 nuclei at z=18
# Identified 491 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 536 nuclei at z=19
# Identified 536 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 541 nuclei at z=20
# Identified 541 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 556 nuclei at z=21
# Identified 556 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 569 nuclei at z=22
# Identified 569 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 587 nuclei at z=23
# Identified 587 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 567 nuclei at z=24
# Identified 567 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 570 nuclei at z=25
# Identified 570 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 542 nuclei at z=26
# Identified 542 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 512 nuclei at z=27
# Identified 512 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 529 nuclei at z=28
# Identified 529 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 495 nuclei at z=29
# Identified 495 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 452 nuclei at z=30
# Identified 452 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=31
# Identified 425 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 416 nuclei at z=32
# Identified 416 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 425 nuclei at z=33
# Identified 425 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 432 nuclei at z=34
# Identified 432 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 402 nuclei at z=35
# Identified 402 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 399 nuclei at z=36
# Identified 399 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 379 nuclei at z=37
# Identified 379 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 381 nuclei at z=38
# Identified 381 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 333 nuclei at z=39
# Identified 333 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 310 nuclei at z=40
# Identified 310 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 273 nuclei at z=41
# Identified 273 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 237 nuclei at z=42
# Identified 237 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 220 nuclei at z=43
# Identified 220 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 255 nuclei at z=44
# Identified 255 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 347 nuclei at z=45
# Identified 347 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 391 nuclei at z=46
# Identified 391 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 406 nuclei at z=47
# Identified 406 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 388 nuclei at z=48
# Identified 388 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 404 nuclei at z=49
# Identified 404 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 393 nuclei at z=50
# Identified 393 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 400 nuclei at z=51
# Identified 400 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 391 nuclei at z=52
# Identified 391 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 380 nuclei at z=53
# Identified 380 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 385 nuclei at z=54
# Identified 385 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 379 nuclei at z=55
# Identified 379 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 365 nuclei at z=56
# Identified 365 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 333 nuclei at z=57
# Identified 333 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 326 nuclei at z=58
# Identified 326 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 314 nuclei at z=59
# Identified 314 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 301 nuclei at z=60
# Identified 301 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 273 nuclei at z=61
# Identified 273 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 256 nuclei at z=62
# Identified 256 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 235 nuclei at z=63
# Identified 235 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 217 nuclei at z=64
# Identified 217 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 202 nuclei at z=65
# Identified 202 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 192 nuclei at z=66
# Identified 192 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 180 nuclei at z=67
# Identified 180 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 165 nuclei at z=68
# Identified 165 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 125 nuclei at z=69
# Identified 125 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 102 nuclei at z=70
# Identified 102 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 79 nuclei at z=71
# Identified 79 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 64 nuclei at z=72
# Identified 64 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 48 nuclei at z=73
# Identified 48 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=246
# Identified 37 nuclei at z=74
# Identified 37 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 34 nuclei at z=75
# Identified 34 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 26 nuclei at z=76
# Identified 26 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=248
# Identified 17 nuclei at z=77
# Identified 17 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=252
# Identified 24 nuclei at z=78
# Identified 24 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=234
# Identified 9 nuclei at z=79
# Identified 9 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 5 nuclei at z=80
# Identified 5 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 1 nuclei at z=81
# Identified 1 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:04:59,545 [INFO] No cell pixels found.
# Identified 0 nuclei at z=82
# Identified 0 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:00,031 [INFO] No cell pixels found.
# Identified 0 nuclei at z=83
# Identified 0 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:00,538 [INFO] No cell pixels found.
# Identified 0 nuclei at z=84
# Identified 0 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:01,032 [INFO] No cell pixels found.
# Identified 0 nuclei at z=85
# Identified 0 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:01,594 [INFO] No cell pixels found.
# Identified 0 nuclei at z=86
# Identified 0 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=213
# 2025-08-15 13:05:02,200 [INFO] No cell pixels found.
# Identified 0 nuclei at z=87
# Identified 0 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:02,719 [INFO] No cell pixels found.
# Identified 0 nuclei at z=88
# Identified 0 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:03,214 [INFO] No cell pixels found.
# Identified 0 nuclei at z=89
# Identified 0 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=90
# Identified 0 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 2 nuclei at z=91
# Identified 2 nuclei
# ROIs saved to ../results/20250813 C P14 U34-B3-488 Chymotrypsin-B2-647 DAPI/20250813 C sample 7 stack_rois.npy
# Processing 20250813 C sample 6 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF488-T1', 'AF647-T1', 'DAPI-T2']}
# Image shape: (92, 3, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 92
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF488-T1'), (1, 'AF647-T1')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:05:27,713 [INFO] No cell pixels found.
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=2
# Identified 6 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 6 nuclei at z=3
# Identified 6 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 3 nuclei at z=4
# Identified 3 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 7 nuclei at z=5
# Identified 7 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 8 nuclei at z=6
# Identified 8 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 39 nuclei at z=7
# Identified 39 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 77 nuclei at z=8
# Identified 77 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 124 nuclei at z=9
# Identified 124 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 166 nuclei at z=10
# Identified 166 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 207 nuclei at z=11
# Identified 207 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 232 nuclei at z=12
# Identified 232 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 254 nuclei at z=13
# Identified 254 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 318 nuclei at z=14
# Identified 318 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 364 nuclei at z=15
# Identified 364 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 397 nuclei at z=16
# Identified 397 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 421 nuclei at z=17
# Identified 421 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 443 nuclei at z=18
# Identified 443 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 478 nuclei at z=19
# Identified 478 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 496 nuclei at z=20
# Identified 496 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 523 nuclei at z=21
# Identified 523 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 534 nuclei at z=22
# Identified 534 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 567 nuclei at z=23
# Identified 567 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 572 nuclei at z=24
# Identified 572 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 591 nuclei at z=25
# Identified 591 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 643 nuclei at z=26
# Identified 643 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 652 nuclei at z=27
# Identified 652 nuclei
# ...
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 532 nuclei at z=58
# Identified 532 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 570 nuclei at z=59
# Identified 570 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 589 nuclei at z=60
# Identified 589 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 631 nuclei at z=61
# Identified 631 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 637 nuclei at z=62
# Identified 637 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 680 nuclei at z=63
# Identified 680 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 651 nuclei at z=64
# Identified 651 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 610 nuclei at z=65
# Identified 610 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 662 nuclei at z=66
# Identified 662 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 627 nuclei at z=67
# Identified 627 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 634 nuclei at z=68
# Identified 634 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 633 nuclei at z=69
# Identified 633 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 614 nuclei at z=70
# Identified 614 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 587 nuclei at z=71
# Identified 587 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 550 nuclei at z=72
# Identified 550 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 556 nuclei at z=73
# Identified 556 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 521 nuclei at z=74
# Identified 521 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=253
# Identified 488 nuclei at z=75
# Identified 488 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 464 nuclei at z=76
# Identified 464 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 432 nuclei at z=77
# Identified 432 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 427 nuclei at z=78
# Identified 427 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 393 nuclei at z=79
# Identified 393 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=228
# Identified 358 nuclei at z=80
# Identified 358 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 321 nuclei at z=81
# Identified 321 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 304 nuclei at z=82
# Identified 304 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=231
# Identified 260 nuclei at z=83
# Identified 260 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=212
# Identified 208 nuclei at z=84
# Identified 208 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=211
# Identified 167 nuclei at z=85
# Identified 167 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=201
# Identified 139 nuclei at z=86
# Identified 139 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 121 nuclei at z=87
# Identified 121 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=204
# Identified 101 nuclei at z=88
# Identified 101 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=198
# Identified 81 nuclei at z=89
# Identified 81 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 40 nuclei at z=90
# Identified 40 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=203
# Identified 21 nuclei at z=91
# Identified 21 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=184
# Identified 19 nuclei at z=92
# Identified 19 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=173
# Identified 28 nuclei at z=93
# Identified 28 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=165
# Identified 16 nuclei at z=94
# Identified 16 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=173
# Identified 12 nuclei at z=95
# Identified 12 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 4 nuclei at z=96
# Identified 4 nuclei
# ROIs saved to ../results/20250813 A P14 P1-B1-546 P2-B2-647 P1-antisense-B3-488 DAPI/20250813 A sample 7 stack_rois.npy
# Processing 20250813 A sample 8 stack.czi
# Metadata: {'rgb': False, 'channel_axis': 2, 'translate': (0.0, 0.0, 0.0, 0.0), 'scale': (1.0, 1.0, 0.0974884033203125, 0.0974884033203125), 'contrast_limits': None, 'name': ['AF546-T1', 'AF488-T2', 'DAPI-T3', 'AF647-T3']}
# Image shape: (97, 4, 2048, 2048)
# Number of NaN pixels: 0
# Pixel size: 0.0974884033203125 um
# XY resolution: 2048 pixels
# Nucleus diameter: 30.77289090624511 pixels
# Z slices: 97
# Z resolution: 1.0 um
# DAPI channel index: 2
# Non-DAPI channels: [(0, 'AF546-T1'), (1, 'AF488-T2'), (3, 'AF647-T3')]
# Z=0 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=67
# Identified 0 nuclei at z=0
# Identified 0 nuclei
# Z=1 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=58
# Identified 0 nuclei at z=1
# Identified 0 nuclei
# Z=2 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=54
# 2025-08-15 13:49:33,092 [INFO] No cell pixels found.
# Identified 0 nuclei at z=2
# Identified 0 nuclei
# Z=3 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=44
# 2025-08-15 13:49:33,700 [INFO] No cell pixels found.
# Identified 0 nuclei at z=3
# Identified 0 nuclei
# Z=4 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=105
# Identified 0 nuclei at z=4
# Identified 0 nuclei
# Z=5 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=130
# 2025-08-15 13:49:34,918 [INFO] No cell pixels found.
# Identified 0 nuclei at z=5
# Identified 0 nuclei
# Z=6 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=156
# Identified 0 nuclei at z=6
# Identified 0 nuclei
# Z=7 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=225
# Identified 0 nuclei at z=7
# Identified 0 nuclei
# Z=8 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=242
# Identified 0 nuclei at z=8
# Identified 0 nuclei
# Z=9 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=216
# Identified 0 nuclei at z=9
# Identified 0 nuclei
# Z=10 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:49:37,999 [INFO] No cell pixels found.
# Identified 0 nuclei at z=10
# Identified 0 nuclei
# Z=11 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# 2025-08-15 13:49:38,452 [INFO] No cell pixels found.
# Identified 0 nuclei at z=11
# Identified 0 nuclei
# Z=12 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:49:38,929 [INFO] No cell pixels found.
# Identified 0 nuclei at z=12
# Identified 0 nuclei
# Z=13 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# 2025-08-15 13:49:39,394 [INFO] No cell pixels found.
# Identified 0 nuclei at z=13
# Identified 0 nuclei
# Z=14 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 0 nuclei at z=14
# Identified 0 nuclei
# Z=15 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 8 nuclei at z=15
# Identified 8 nuclei
# Z=16 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 27 nuclei at z=16
# Identified 27 nuclei
# Z=17 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 38 nuclei at z=17
# Identified 38 nuclei
# Z=18 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 37 nuclei at z=18
# Identified 37 nuclei
# Z=19 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 49 nuclei at z=19
# Identified 49 nuclei
# Z=20 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 47 nuclei at z=20
# Identified 47 nuclei
# Z=21 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 46 nuclei at z=21
# Identified 46 nuclei
# Z=22 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 42 nuclei at z=22
# Identified 42 nuclei
# Z=23 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 52 nuclei at z=23
# Identified 52 nuclei
# Z=24 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 82 nuclei at z=24
# Identified 82 nuclei
# Z=25 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 118 nuclei at z=25
# Identified 118 nuclei
# Z=26 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 154 nuclei at z=26
# Identified 154 nuclei
# Z=27 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 198 nuclei at z=27
# Identified 198 nuclei
# Z=28 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 257 nuclei at z=28
# Identified 257 nuclei
# Z=29 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 300 nuclei at z=29
# Identified 300 nuclei
# Z=30 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 355 nuclei at z=30
# Identified 355 nuclei
# Z=31 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 410 nuclei at z=31
# Identified 410 nuclei
# Z=32 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 419 nuclei at z=32
# Identified 419 nuclei
# Z=33 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 478 nuclei at z=33
# Identified 478 nuclei
# Z=34 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 471 nuclei at z=34
# Identified 471 nuclei
# Z=35 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 505 nuclei at z=35
# Identified 505 nuclei
# Z=36 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 485 nuclei at z=36
# Identified 485 nuclei
# Z=37 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 479 nuclei at z=37
# Identified 479 nuclei
# Z=38 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 470 nuclei at z=38
# Identified 470 nuclei
# Z=39 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 476 nuclei at z=39
# Identified 476 nuclei
# Z=40 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 502 nuclei at z=40
# Identified 502 nuclei
# Z=41 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 500 nuclei at z=41
# Identified 500 nuclei
# Z=42 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 505 nuclei at z=42
# Identified 505 nuclei
# Z=43 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 525 nuclei at z=43
# Identified 525 nuclei
# Z=44 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 532 nuclei at z=44
# Identified 532 nuclei
# Z=45 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=45
# Identified 551 nuclei
# Z=46 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 538 nuclei at z=46
# Identified 538 nuclei
# Z=47 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 545 nuclei at z=47
# Identified 545 nuclei
# Z=48 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 576 nuclei at z=48
# Identified 576 nuclei
# Z=49 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 575 nuclei at z=49
# Identified 575 nuclei
# Z=50 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 562 nuclei at z=50
# Identified 562 nuclei
# Z=51 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 574 nuclei at z=51
# Identified 574 nuclei
# Z=52 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=52
# Identified 578 nuclei
# Z=53 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 580 nuclei at z=53
# Identified 580 nuclei
# Z=54 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 548 nuclei at z=54
# Identified 548 nuclei
# Z=55 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 551 nuclei at z=55
# Identified 551 nuclei
# Z=56 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 543 nuclei at z=56
# Identified 543 nuclei
# Z=57 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 545 nuclei at z=57
# Identified 545 nuclei
# Z=58 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 509 nuclei at z=58
# Identified 509 nuclei
# Z=59 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 495 nuclei at z=59
# Identified 495 nuclei
# Z=60 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 485 nuclei at z=60
# Identified 485 nuclei
# Z=61 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 473 nuclei at z=61
# Identified 473 nuclei
# Z=62 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 506 nuclei at z=62
# Identified 506 nuclei
# Z=63 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 520 nuclei at z=63
# Identified 520 nuclei
# Z=64 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 569 nuclei at z=64
# Identified 569 nuclei
# Z=65 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 623 nuclei at z=65
# Identified 623 nuclei
# Z=66 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 653 nuclei at z=66
# Identified 653 nuclei
# Z=67 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 618 nuclei at z=67
# Identified 618 nuclei
# Z=68 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 624 nuclei at z=68
# Identified 624 nuclei
# Z=69 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 602 nuclei at z=69
# Identified 602 nuclei
# Z=70 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 625 nuclei at z=70
# Identified 625 nuclei
# Z=71 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 595 nuclei at z=71
# Identified 595 nuclei
# Z=72 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=245
# Identified 606 nuclei at z=72
# Identified 606 nuclei
# Z=73 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=250
# Identified 567 nuclei at z=73
# Identified 567 nuclei
# Z=74 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 554 nuclei at z=74
# Identified 554 nuclei
# Z=75 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=246
# Identified 555 nuclei at z=75
# Identified 555 nuclei
# Z=76 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=241
# Identified 568 nuclei at z=76
# Identified 568 nuclei
# Z=77 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 578 nuclei at z=77
# Identified 578 nuclei
# Z=78 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=229
# Identified 507 nuclei at z=78
# Identified 507 nuclei
# Z=79 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 483 nuclei at z=79
# Identified 483 nuclei
# Z=80 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=243
# Identified 447 nuclei at z=80
# Identified 447 nuclei
# Z=81 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=255
# Identified 441 nuclei at z=81
# Identified 441 nuclei
# Z=82 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=224
# Identified 405 nuclei at z=82
# Identified 405 nuclei
# Z=83 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=211
# Identified 397 nuclei at z=83
# Identified 397 nuclei
# Z=84 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=181
# Identified 361 nuclei at z=84
# Identified 361 nuclei
# Z=85 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=226
# Identified 333 nuclei at z=85
# Identified 333 nuclei
# Z=86 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=173
# Identified 310 nuclei at z=86
# Identified 310 nuclei
# Z=87 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=180
# Identified 280 nuclei at z=87
# Identified 280 nuclei
# Z=88 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=191
# Identified 263 nuclei at z=88
# Identified 263 nuclei
# Z=89 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=191
# Identified 236 nuclei at z=89
# Identified 236 nuclei
# Z=90 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=211
# Identified 199 nuclei at z=90
# Identified 199 nuclei
# Z=91 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=232
# Identified 156 nuclei at z=91
# Identified 156 nuclei
# Z=92 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=189
# Identified 149 nuclei at z=92
# Identified 149 nuclei
# Z=93 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=186
# Identified 110 nuclei at z=93
# Identified 110 nuclei
# Z=94 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=150
# Identified 77 nuclei at z=94
# Identified 77 nuclei
# Z=95 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=159
# Identified 37 nuclei at z=95
# Identified 37 nuclei
# Z=96 | shape=(2048, 2048) | dtype=uint8 | min=0 | max=168
# Identified 13 nuclei at z=96
# Identified 13 nuclei
# ROIs saved to ../results/20250813 A P14 P1-B1-546 P2-B2-647 P1-antisense-B3-488 DAPI/20250813 A sample 8 stack_rois.npy
